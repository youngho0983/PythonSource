# %%
# 파일 출력

# %%
f = open("data/test1.txt","w")
print(dir(f))
print(f)
f.write("hello")
f.close()
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']
# <_io.TextIOWrapper name='data/test1.txt' mode='w' encoding='cp949'>

# %%
f=open("data/test1.txt","w",encoding="utf-8")
f.write("안녕하세요\n만나서 반갑습니다.")

f.close()

# %%
f=open("data/test1.txt","w",encoding="utf-8")
for i in range(1,11):
    data = "%d 번째 줄 입니다. \n" %i
    f.write(data)
f.close()

# %%
f=open("data/test1.txt","a",encoding="utf-8")
for i in range(1,11):
    data= "안녕하세요\n"
    f.write(data)
f.close()

# %%
#리스트 값 파일에 쓰기
list1=[1,2,3,4,5,6,7]
f=open("data/test1.txt","a",encoding="utf-8")
f.write(str(list1) )
f.close()

# %%
list1=["him","park","choi","a"]
f=open("data/test1.txt","w",encoding="utf-8")
f.writelines(list1)
f.close()

# %%
# close  자동 처리

with open("data/test1.txt","a",encoding="utf-8")as f:
    list1=["kim\n","park\n","choi\n"]
    f.writelines(list1)

# %%
with open("data/test1.txt","a",encoding="utf-8")as f:
    dict1={
        "name":"hong",
        "age":25,
        "addr":"서울"
    }
    for k,v in dict1.items():
        f.writelines("{}:{}\n".format(k,v))

# %%
# 1000명의 키와 몸무게를 랜덤하게 생성해 파일에 기록 하기
import random

hanguls = list("가나다라마바사아자차카타파하")

with open("data/test.txt","w",encoding="utf-8")as f:
    for i in range(1000):
        #random.choice => 원소중 아무거나 하나 꺼내기
        name =random.choice(hanguls)+random.choice(hanguls)
        weight=random.randrange(40,100)
        height=random.randrange(140,200)
        f.writelines("{},{},{}\n".format(name,weight,height))

# %%
f=open("data/review.txt","r",encoding="utf-8")
content =f.read()
print(content)
f.close()
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt","r",encoding="utf-8") as f:
    content =f.read()
    print(content)
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt","r",encoding="utf-8")as f:
    for c in f:
        #print(c)
        #print(c,end="")
        print(c.strip())
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt","r",encoding="utf-8")as f:
    line=" "
    while(line):
        line = f.readline()
        print(line)
# Out:
# The film, projected in the form of animation,
#
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
#
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
#
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
#
# who are twins, but they constantly fight over unresolved issues planted in their minds
#
# by external forces from within their very own units.

# %%
with open("data/review.txt","r",encoding="utf-8")as f:
    print(f.readlines())
# Out:
# ['The film, projected in the form of animation,\n', 'imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,\n', 'which eventually paves the path for gaining a fresh perspective on an age-old problem.\n', 'The story also happens to centre around two parallel characters, Shundi King and Hundi King,\n', 'who are twins, but they constantly fight over unresolved issues planted in their minds\n', 'by external forces from within their very own units.\n']

# %%
with open("data/score.txt","r",encoding="utf-8")as f:
    print(f.read())
# Out:
# 95
# 78
# 92
# 89
# 100
# 66

# %%
score=[]
with open("data/score.txt","r",encoding="utf-8")as f:
    for num in f:
        score.append(int(num) )
print(score)
index=len(score);
sum_score=0
for value in score:
    print(value)
    sum_score+=value
    

ava_score=sum_score/index
print(sum_score)
print(ava_score)
# Out:
# [95, 78, 92, 89, 100, 66]
# 95
# 78
# 92
# 89
# 100
# 66
# 520
# 86.66666666666667

# %%
#score.txt 를 읽어서 총점과 평균을 구한 후 result.txt 파일에 쓰자
score=[]
with open("data/score.txt","r",encoding="utf-8") as f:
    for num in f:
        score.append(int(f.readline()))
sum_result=sum(score)
ava_result=sum_result/len(score)


with open("data/result.txt","w",encoding="utf-8") as f:
    f.write("총 합은 {} \n평균은 {:0.3f}".format(sum_result,ava_result))

# %%
import os

content =""
fName =""
fName =input ("파일명을 입력해 주세요")
path="data/"+fName

if os.path.exists(path):
    with open(path, "r",encoding="utf-8")as inFp:
        content =inFp.read()
        
    
    oName= input("저장할 폴더와 이름을 입력하세요 ")
    
    with open(oName, "w",encoding="utf-8")as outFp:
        outFp.writelines(content)
else:
    print("%s 파일이 없습니다. " %fName)
# Out:
# 파일명을 입력해 주세요score.txt
# 저장할 폴더와 이름을 입력하세요 c:/test.txt

# %%
#info.txt 파일 읽어서 BMI 지수를 계산 한 후 출력하기
# 계산 값이 >=25 과체중 , >=18.5 정상체중 , 저체중
# bmi= 몸무게 /키/100    **2


with open("data/info.txt","r",encoding="utf-8") as f:
    with open("data/info2.txt","w",encoding="utf-8") as f2:
        content="  "
        while(content):
            content=f.readline()
            
            data=content.split(",")
            
            name=data[0]
            print(name)
            weight=int(data[1])
            print(weight)
            height=int(data[2])
           
            bmi=(weight/(height/100))*(weight/(height/100))
           
            f2.write(name)
            f2.write("님의 bmi는 ")
            f2.write(str(bmi))
            f2.write("\n")
# Out:
# 자파
# 40
#  마가
# 87
#  타사
# 68
#  다나
# 51
#  다가
# 49
#  타차
# 48
#  차아
# 72
#  가파
# 54
#  파바
# 46
#  타다
# 61
#  자파
# 40
#  바파
# 61
#  타나
# 77
#  사아
# 83
#  아카
# 76
#  파아
# 48
#  바아
# 87
#  타사
# 77
#  하바
# 66
#  파가
# 79
#  나파
# 89
#  라사
# 62
#  파파
# 78
#  파자
# 80
#  아사
# 94
#  카아
# 98
#  아타
# 93
#  다자
# 63
#  하사
# 90
#  파사
# 75
#  타아
# 56
#  사차
# 58
#  파바
# 67
#  차마
# 70
#  마카
# 41
#  타가
# 50
#  아하
# 79
#  나하
# 42
#  차카
# 88
#  하타
# 71
#  나하
# 40
#  하카
# 99
#  하자
# 48
#  자사
# 59
#  하나
# 92
#  아가
# 84
#  하나
# 80
#  사바
# 91
#  아아
# 55
#  자파
# 85
#  차아
# 44
#  라파
# 82
#  나자
# 46
#  나타
# 49
#  나사
# 92
#  하자
# 47
#  가타
# 73
#  파다
# 66
#  파타
# 69
#  차차
# 74
#  라카
# 52
#  카마
# 53
#  가하
# 59
#  하다
# 71
#  라라
# 66
#  나하
# 79
#  카하
# 74
#  아하
# 58
#  가다
# 57
#  마파
# 97
#  라다
# 90
#  파파
# 83
#  하아
# 65
#  다사
# 71
#  자차
# 55
#  아가
# 54
#  마카
# 58
#  나가
# 64
#  가아
# 75
#  카차
# 59
#  다아
# 56
#  타마
# 97
#  차바
# 80
#  타가
# 51
#  바마
# 63
#  자라
# 74
#  하마
# 62
#  라하
# 53
#  자나
# 43
#  사차
# 95
#  바마
# 76
#  나가
# 60
#  타다
# 55
#  가가
# 64
#  차나
# 75
#  아사
# 68
#  라사
# 89
#  아바
# 57
#  가다
# 50
#  차하
# 98
#  다바
# 89
#  파하
# 67
#  자나
# 91
#  다가
# 60
#  사파
# 94
#  가사
# 45
#  차하
# 57
#  가카
# 52
#  사바
# 86
#  사라
# 72
#  차파
# 43
#  사자
# 98
#  마차
# 44
#  바하
# 66
#  마카
# 62
#  아나
# 80
#  자사
# 44
#  다나
# 92
#  차라
# 50
#  다나
# 42
#  바카
# 84
#  타자
# 71
#  가바
# 99
#  하사
# 58
#  타라
# 86
#  가하
# 43
#  자라
# 74
#  카파
# 72
#  가차
# 97
#  파라
# 78
#  마라
# 57
#  가나
# 61
#  카사
# 73
#  파아
# 68
#  아마
# 60
#  아라
# 87
#  바다
# 69
#  가하
# 58
#  가나
# 57
#  나가
# 60
#  타차
# 56
#  바아
# 44
#  하나
# 66
#  다사
# 91
#  가카
# 56
#  마가
# 41
#  하바
# 77
#  아사
# 83
#  나가
# 67
#  파가
# 60
#  자바
# 99
#  타차
# 61
#  차아
# 92
#  파바
# 52
#  다가
# 74
#  하다
# 74
#  마하
# 82
#  카타
# 56
#  다마
# 47
#  하라
# 70
#  파라
# 59
#  마라
# 67
#  가타
# 82
#  카자
# 44
#  아마
# 41
#  자다
# 72
#  다바
# 61
#  바마
# 66
#  타나
# 61
#  마사
# 71
#  사타
# 99
#  카자
# 79
#  라하
# 47
#  마라
# 98
#  다사
# 96
#  다하
# 90
#  카하
# 44
#  자아
# 61
#  사타
# 70
#  나타
# 87
#  하자
# 76
#  라마
# 99
#  타가
# 53
#  차타
# 40
#  바사
# 54
#  마파
# 78
#  나가
# 51
#  사자
# 73
#  사아
# 63
#  카마
# 75
#  하사
# 67
#  바차
# 58
#  나파
# 61
#  차파
# 63
#  자타
# 98
#  가차
# 61
#  바가
# 96
#  마바
# 86
#  바파
# 57
#  하나
# 79
#  마나
# 87
#  라타
# 92
#  나다
# 54
#  다파
# 79
#  가파
# 57
#  사카
# 58
#  카타
# 83
#  자가
# 52
#  차다
# 42
#  타차
# 99
#  다바
# 49
#  차바
# 83
#  라아
# 46
#  마타
# 99
#  다하
# 67
#  가차
# 71
#  가아
# 59
#  바다
# 70
#  타파
# 44
#  가바
# 88
#  파아
# 50
#  마아
# 82
#  나카
# 97
#  마카
# 48
#  하가
# 54
#  마아
# 72
#  바바
# 92
#  차자
# 46
#  자바
# 91
#  가차
# 49
#  다차
# 40
#  아다
# 93
#  다차
# 46
#  바타
# 45
#  아라
# 92
#  자바
# 57
#  사라
# 76
#  라차
# 85
#  카바
# 40
#  아자
# 43
#  자하
# 79
#  다나
# 76
#  하나
# 68
#  아차
# 45
#  나사
# 87
#  다자
# 83
#  하파
# 43
#  바사
# 92
#  마하
# 90
#  나자
# 43
#  나마
# 48
#  카차
# 75
#  라차
# 93
#  나차
# 97
#  하라
# 70
#  카사
# 71
#  카마
# 97
#  바다
# 71
#  하카
# 94
#  타다
# 84
#  바파
# 59
#  자라
# 45
#  카자
# 65
#  나나
# 93
#  라마
# 71
#  라가
# 42
#  차가
# 48
#  파자
# 89
#  하나
# 57
#  차타
# 50
#  바타
# 90
#  라카
# 87
#  다파
# 91
#  자사
# 87
#  자바
# 75
#  라카
# 59
#  라나
# 93
#  하파
# 84
#  하아
# 90
#  가바
# 84
#  타카
# 86
#  파카
# 99
#  나아
# 62
#  나카
# 76
#  라타
# 82
#  자타
# 60
#  차차
# 89
#  카바
# 93
#  마라
# 90
#  바라
# 55
#  나라
# 91
#  사카
# 60
#  라아
# 99
#  바카
# 54
#  하하
# 44
#  파차
# 63
#  아자
# 45
#  차마
# 85
#  다자
# 80
#  가라
# 42
#  다자
# 59
#  아다
# 53
#  마하
# 41
#  가바
# 91
#  아바
# 79
#  아카
# 55
#  사사
# 85
#  카아
# 50
#  마라
# 55
#  다차
# 90
#  사파
# 82
#  사라
# 50
#  라차
# 94
#  사카
# 45
#  사사
# 60
#  마가
# 69
#  아마
# 48
#  라자
# 53
#  타타
# 59
#  하바
# 79
#  하바
# 47
#  자가
# 66
#  마카
# 78
#  다가
# 43
#  하아
# 80
#  나타
# 83
#  타타
# 58
#  마마
# 55
#  바사
# 65
#  파자
# 69
#  타파
# 78
#  다마
# 77
#  타바
# 53
#  자마
# 52
#  타가
# 67
#  다가
# 90
#  라라
# 64
#  라라
# 49
#  차사
# 79
#  바라
# 53
#  마나
# 84
#  마자
# 69
#  다하
# 40
#  타하
# 71
#  차가
# 81
#  파바
# 76
#  하파
# 52
#  바나
# 72
#  타타
# 91
#  하바
# 64
#  마바
# 85
#  사차
# 66
#  자카
# 86
#  나아
# 79
#  나파
# 42
#  하카
# 70
#  하카
# 73
#  마라
# 98
#  사나
# 82
#  다사
# 43
#  나타
# 89
#  타가
# 55
#  하아
# 67
#  파하
# 41
#  마다
# 85
#  하라
# 88
#  하나
# 99
#  바나
# 86
#  사나
# 84
#  타파
# 86
#  마마
# 90
#  바하
# 56
#  자아
# 94
#  나카
# 47
#  가라
# 87
#  카나
# 97
#  나카
# 92
#  바차
# 40
#  사차
# 98
#  바하
# 41
#  아자
# 71
#  바라
# 47
#  카바
# 75
#  바카
# 95
#  나타
# 73
#  카바
# 51
#  차아
# 65
#  자아
# 69
#  다바
# 57
#  아차
# 82
#  바타
# 59
#  카바
# 75
#  다가
# 59
#  가가
# 49
#  차사
# 67
#  나다
# 43
#  바바
# 96
#  바마
# 86
#  하바
# 51
#  가타
# 88
#  하라
# 40
#  아바
# 94
#  카바
# 52
#  차나
# 55
#  아하
# 81
#  라바
# 80
#  타바
# 52
#  마아
# 46
#  하하
# 66
#  파파
# 80
#  하자
# 96
#  차하
# 71
#  가바
# 83
#  사바
# 79
#  아나
# 83
#  자다
# 72
#  타파
# 49
#  사나
# 48
#  아자
# 98
#  마바
# 93
#  마아
# 44
#  자나
# 50
#  카파
# 78
#  파사
# 56
#  차다
# 49
#  자차
# 68
#  아타
# 61
#  마나
# 41
#  나타
# 42
#  카나
# 78
#  사아
# 81
#  카자
# 48
#  아아
# 73
#  타자
# 77
#  다나
# 40
#  다타
# 91
#  가가
# 83
#  나아
# 97
#  다차
# 59
#  바마
# 69
#  차카
# 60
#  나라
# 62
#  바마
# 63
#  가아
# 57
#  하다
# 89
#  아나
# 68
#  바다
# 81
#  나나
# 54
#  아마
# 71
#  바가
# 57
#  자다
# 41
#  사사
# 54
#  나타
# 98
#  가마
# 86
#  아가
# 51
#  바라
# 48
#  자아
# 82
#  사타
# 86
#  자차
# 73
#  카가
# 95
#  하하
# 48
#  자아
# 78
#  사바
# 78
#  다라
# 59
#  다카
# 47
#  자마
# 67
#  가나
# 88
#  가차
# 90
#  타자
# 97
#  사차
# 77
#  아마
# 45
#  다라
# 75
#  카카
# 67
#  타바
# 94
#  하바
# 69
#  하마
# 76
#  파라
# 65
#  파카
# 86
#  사카
# 40
#  카가
# 89
#  가나
# 99
#  카하
# 76
#  자바
# 67
#  파바
# 84
#  카자
# 95
#  카카
# 52
#  카파
# 74
#  카자
# 78
#  가자
# 70
#  아다
# 98
#  나아
# 41
#  차하
# 40
#  다가
# 67
#  타가
# 56
#  가하
# 94
#  파하
# 91
#  카나
# 64
#  마가
# 55
#  카파
# 96
#  가자
# 58
#  사자
# 79
#  자자
# 86
#  타파
# 89
#  다다
# 93
#  라나
# 62
#  다라
# 72
#  파카
# 53
#  자차
# 66
#  카사
# 63
#  자자
# 46
#  파파
# 84
#  차다
# 95
#  바바
# 77
#  카라
# 71
#  다바
# 41
#  카가
# 43
#  파사
# 53
#  자아
# 43
#  차타
# 96
#  사하
# 84
#  라아
# 80
#  차카
# 58
#  나타
# 52
#  다하
# 54
#  마가
# 43
#  아타
# 63
#  사바
# 46
#  타아
# 45
#  하아
# 95
#  바자
# 40
#  차사
# 47
#  파마
# 75
#  하자
# 48
#  파차
# 51
#  타자
# 59
#  차마
# 78
#  하아
# 66
#  차사
# 66
#  바사
# 79
#  카타
# 95
#  가다
# 68
#  바사
# 89
#  아마
# 41
#  나다
# 47
#  다나
# 77
#  라타
# 53
#  자마
# 44
#  바차
# 67
#  바자
# 80
#  나바
# 84
#  가나
# 61
#  나하
# 66
#  타타
# 49
#  가하
# 53
#  파아
# 68
#  가라
# 81
#  사하
# 93
#  아차
# 73
#  나나
# 51
#  나하
# 72
#  카타
# 61
#  라파
# 50
#  아마
# 76
#  차나
# 55
#  타자
# 79
#  카마
# 54
#  하다
# 63
#  파라
# 97
#  마사
# 53
#  타바
# 55
#  사라
# 73
#  차바
# 62
#  바다
# 99
#  자바
# 44
#  아나
# 85
#  아사
# 73
#  카라
# 94
#  바사
# 76
#  다바
# 60
#  바하
# 99
#  카카
# 69
#  카하
# 62
#  가마
# 97
#  타마
# 59
#  카아
# 94
#  카라
# 90
#  하타
# 66
#  라바
# 47
#  차마
# 45
#  타마
# 74
#  라바
# 99
#  파가
# 50
#  가다
# 81
#  가다
# 64
#  타파
# 46
#  마마
# 72
#  하차
# 91
#  차나
# 56
#  가아
# 92
#  자차
# 62
#  카타
# 67
#  다바
# 48
#  사차
# 95
#  카타
# 40
#  아가
# 74
#  나마
# 85
#  타라
# 91
#  아바
# 63
#  자하
# 66
#  라카
# 78
#  하아
# 88
#  아타
# 45
#  마타
# 70
#  타라
# 58
#  하가
# 42
#  사다
# 82
#  하파
# 60
#  라카
# 72
#  라나
# 89
#  가타
# 54
#  차타
# 77
#  가가
# 47
#  타라
# 81
#  마파
# 89
#  나카
# 71
#  자라
# 96
#  사가
# 90
#  나차
# 49
#  다타
# 76
#  가자
# 73
#  타하
# 48
#  아카
# 41
#  아하
# 97
#  아타
# 49
#  바자
# 66
#  파가
# 67
#  하다
# 85
#  아사
# 64
#  파마
# 81
#  파차
# 98
#  가타
# 87
#  카라
# 80
#  마아
# 43
#  바다
# 54
#  카가
# 86
#  라자
# 75
#  타라
# 49
#  다아
# 74
#  마사
# 82
#  사카
# 77
#  마자
# 73
#  하카
# 61
#  나마
# 76
#  가아
# 50
#  사마
# 66
#  차차
# 95
#  라라
# 82
#  나파
# 89
#  아파
# 54
#  나사
# 57
#  하파
# 98
#  아파
# 82
#  아라
# 61
#  바차
# 90
#  마카
# 74
#  자다
# 96
#  자가
# 40
#  마타
# 72
#  차라
# 81
#  타나
# 46
#  자아
# 72
#  라자
# 86
#  카자
# 82
#  하바
# 95
#  다자
# 72
#  파자
# 93
#  아나
# 64
#  다타
# 80
#  자자
# 53
#  타아
# 86
#  라마
# 53
#  하사
# 82
#  하사
# 78
#  카사
# 56
#  바사
# 77
#  라바
# 71
#  아자
# 51
#  자카
# 98
#  라타
# 50
#  자타
# 73
#  카아
# 69
#  하차
# 91
#  마다
# 47
#  마가
# 77
#  사가
# 50
#  자사
# 58
#  하파
# 50
#  카타
# 94
#  파나
# 47
#  차자
# 45
#  나가
# 48
#  자아
# 59
#  가다
# 63
#  라파
# 40
#  아아
# 89
#  마차
# 60
#  다다
# 86
#  하자
# 42
#  카나
# 51
#  자가
# 59
#  마타
# 74
#  자바
# 89
#  다가
# 75
#  마아
# 44
#  라다
# 53
#  타다
# 74
#  아라
# 60
#  파바
# 45
#  카다
# 60
#  마아
# 57
#  타차
# 73
#  마아
# 65
#  하타
# 60
#  카아
# 87
#  아파
# 92
#  타가
# 49
#  자자
# 60
#  사카
# 72
#  자아
# 67
#  타자
# 66
#  다라
# 77
#  타하
# 45
#  바카
# 89
#  마아
# 99
#  가바
# 61
#  마바
# 51
#  가가
# 78
#  하카
# 79
#  라다
# 84
#  카나
# 57
#  나나
# 78
#  다나
# 96
#  파사
# 63
#  마파
# 95
#  카나
# 64
#  다아
# 95
#  자하
# 76
#  마아
# 85
#  다사
# 94
#  라가
# 50
#  자자
# 79
#  바마
# 94
#  차차
# 50
#  차마
# 49
#  바아
# 84
#  카바
# 54
#  마다
# 42
#  나파
# 66
#  사바
# 78
#  타차
# 47
#  마라
# 66
#  하나
# 52
#  라다
# 68
#  카자
# 94
#  자카
# 68
#  라아
# 53
#  바가
# 47
#  하하
# 65
#  하타
# 87
#  바라
# 51
#  카바
# 82
#  사파
# 99
#  카가
# 53
#  자가
# 64
#  나사
# 69
#  마나
# 99
#  나파
# 60
#  마다
# 48
#  바하
# 47
#  카가
# 56
#  다차
# 72
#  차하
# 98
#  다하
# 98
#  나자
# 48
#  바나
# 60
#  파차
# 86
#  타사
# 90
#  파자
# 69
#  나파
# 96
#  아사
# 45
#  파파
# 64
#  바아
# 52
#  마다
# 80
#  파자
# 89
#  자파
# 56
#  사차
# 41
#  바카
# 41
#  파바
# 64
#  타카
# 61
#  사라
# 82
#  자자
# 57
#  차바
# 75
#  하하
# 88
#  파아
# 46
#  나타
# 75
#  자바
# 56
#  카아
# 44
#  타바
# 78
#  파마
# 77
#  마라
# 82
#  차사
# 75
#  카카
# 83
#  사자
# 78
#  라나
# 95
#  다아
# 41
#  바마
# 60
#  자자
# 60
#  아아
# 68
#  바바
# 43
#  아다
# 70
#  차가
# 57
#  차가
# 85
#  가가
# 79
#  차아
# 61
#  나자
# 77
#  차하
# 97
#  파파
# 81
#  카라
# 57
#  나가
# 87
#  사하
# 46
#  타바
# 42
#  나다
# 49
#  다카
# 71
#  사카
# 49
#  차바
# 46
#  바바
# 83
#  나나
# 81
#  카나
# 51
#  차바
# 83
#  카자
# 70
#  바하
# 44
#  파차
# 45
#  파하
# 60
#  바라
# 67
#  파아
# 87
#  아하
# 75
#  사하
# 95
#  파아
# 61
#  하가
# 87
#  자바
# 92
#  가다
# 60
#  가가
# 89
#  사아
# 80
#  카사
# 43
#  카마
# 60
#  차파
# 98
#  라사
# 59
#  가아
# 84
#  다바
# 60
#  나아
# 82
#  자타
# 56
#  카라
# 63
#  나자
# 43
#  자가
# 51
#  사하
# 63
#  타나
# 69
#  가바
# 86
#  카바
# 44
#  파하
# 57
#  카라
# 96
#  나가
# 49
#  바라
# 82
#  아차
# 65
#  다카
# 73
#  라가
# 50
#  타다
# 56
#  하나
# 73
#  마차
# 61
#  가자
# 98
#  자파
# 66
#  다타
# 61
#  타카
# 76
#  차다
# 77
#  차마
# 83
#  하카
# 53
#  카자
# 44
#  사사
# 85
#  파마
# 67
#  하다
# 56
#  가카
# 54
#  아다
# 41
#  마아
# 91
#  사바
# 70
#  하차
# 60
#  사하
# 96
#  바다
# 42
#  바자
# 44
#  자차
# 46
#  카차
# 97
#  바자
# 71
#  타사
# 96
#  자나
# 45
#  타아
# 73
#  나마
# 82
#  자아
# 95
#  아타
# 42
#  마차
# 93
#  다하
# 52
#  바카
# 45
#  파마
# 63
#  나파
# 42
#  나차
# 54
#  하다
# 75
#  마가
# 52
#  라마
# 70
#  하하
# 82
#  다자
# 57
#  차파
# 84
#  가아
# 98
#  마가
# 56
#  타자
# 81
#  아타
# 58
#  라아
# 90
#  자바
# 64
#  가아
# 67
#  사타
# 43
#  라차
# 61
#  파사
# 53
#  나다
# 92
#  다아
# 73
#  마다
# 83
#  타하
# 81
#  자바
# 47
#  마차
# 76
#  타나
# 52
#  마카
# 84
#  나파
# 66
#  타라
# 89
#  마사
# 81
#  사카
# 81
#  카마
# 97
#  카차
# 48
#  아마
# 69
#  가자
# 53
#  마타
# 98
#  차나
# 54
#  카아
# 82
#  바가
# 64
#  자파
# 76
#  하아
# 86
#  파라
# 97
#  파라
# 40
#  아하
# 69
#  바마
# 82
#  자마
# 61
#  사아
# 79
#  아자
# 46
#  다라
# 55
#  하타
# 83
#  카카
# 64
#  사나
# 43
#  파다
# 95
#  아아
# 83
#  차차
# 67
#  차나
# 70
#  가파
# 68
#  마아
# 44
#  차하
# 40
#  라다
# 71
#  바가
# 89
#  다카
# 71
#  가자
# 94
#  자다
# 95
#  나타
# 82
#  사타
# 53
#  라라
# 99
#  파가
# 69
#  파가
# 67
#  다라
# 70
#  하마
# 79
#  타다
# 64
#  파하
# 92
#  자타
# 52
#  가파
# 86
#  마사
# 76
#  자타
# 68
#  마자
# 57
#  사다
# 49
#  사하
# 88
#  나자
# 61
#  하아
# 48
#  타하
# 73
#  카차
# 87
#  자가
# 91
#  자바
# 70
#  라가
# 48
#  다마
# 51
#  하가
# 57
#  차가
# 77
#  사사
# 74
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-c9f1ad0af998> in <module>
#      14             name=data[0]
#      15             print(name)
# ---> 16             weight=int(data[1])
#      17             print(weight)
#      18             height=int(data[2])
#
# IndexError: list index out of range

# %%
with open("data/info.txt","r",encoding="utf-8")as f:
    for person in f:
        name, weight, height=person.strip().split(",")
        
        bmi=int(weight) / (int (height)/100)**2
        
        result= ""
        if 25<=bmi:
            result="과체중"
        elif 18.5<= bmi:
            result="정상체중"
        else:
            result="저체중"
            
        print("이름 : {} ".format(name))
        print("몸무게: {}".format(weight))
        print("키 : {}".format(height))
        print("BMI: {}".format(bmi))
        print("결과: {}".format(result))
        print()
# Out:
# 이름 : 자파
# 몸무게: 40
# 키 : 184
# BMI: 11.814744801512287
# 결과: 저체중
#
# 이름 : 마가
# 몸무게: 87
# 키 : 188
# BMI: 24.615210502489816
# 결과: 정상체중
#
# 이름 : 타사
# 몸무게: 68
# 키 : 181
# BMI: 20.756387167668876
# 결과: 정상체중
#
# 이름 : 다나
# 몸무게: 51
# 키 : 196
# BMI: 13.275718450645565
# 결과: 저체중
#
# 이름 : 다가
# 몸무게: 49
# 키 : 168
# BMI: 17.361111111111114
# 결과: 저체중
#
# 이름 : 타차
# 몸무게: 48
# 키 : 188
# BMI: 13.58080579447714
# 결과: 저체중
#
# 이름 : 차아
# 몸무게: 72
# 키 : 177
# BMI: 22.981901752370007
# 결과: 정상체중
#
# 이름 : 가파
# 몸무게: 54
# 키 : 164
# BMI: 20.077334919690664
# 결과: 정상체중
#
# 이름 : 파바
# 몸무게: 46
# 키 : 158
# BMI: 18.426534209261334
# 결과: 저체중
#
# 이름 : 타다
# 몸무게: 61
# 키 : 170
# BMI: 21.107266435986162
# 결과: 정상체중
#
# 이름 : 자파
# 몸무게: 40
# 키 : 166
# BMI: 14.51589490492089
# 결과: 저체중
#
# 이름 : 바파
# 몸무게: 61
# 키 : 154
# BMI: 25.72103221453871
# 결과: 과체중
#
# 이름 : 타나
# 몸무게: 77
# 키 : 160
# BMI: 30.078124999999993
# 결과: 과체중
#
# 이름 : 사아
# 몸무게: 83
# 키 : 146
# BMI: 38.937887033214494
# 결과: 과체중
#
# 이름 : 아카
# 몸무게: 76
# 키 : 148
# BMI: 34.69685902118335
# 결과: 과체중
#
# 이름 : 파아
# 몸무게: 48
# 키 : 153
# BMI: 20.504933999743688
# 결과: 정상체중
#
# 이름 : 바아
# 몸무게: 87
# 키 : 162
# BMI: 33.15043438500228
# 결과: 과체중
#
# 이름 : 타사
# 몸무게: 77
# 키 : 176
# BMI: 24.857954545454547
# 결과: 정상체중
#
# 이름 : 하바
# 몸무게: 66
# 키 : 159
# BMI: 26.106562240417702
# 결과: 과체중
#
# 이름 : 파가
# 몸무게: 79
# 키 : 195
# BMI: 20.77580539119001
# 결과: 정상체중
#
# 이름 : 나파
# 몸무게: 89
# 키 : 183
# BMI: 26.575890590940304
# 결과: 과체중
#
# 이름 : 라사
# 몸무게: 62
# 키 : 151
# BMI: 27.19178983377922
# 결과: 과체중
#
# 이름 : 파파
# 몸무게: 78
# 키 : 162
# BMI: 29.721079103795148
# 결과: 과체중
#
# 이름 : 파자
# 몸무게: 80
# 키 : 196
# BMI: 20.824656393169516
# 결과: 정상체중
#
# 이름 : 아사
# 몸무게: 94
# 키 : 175
# BMI: 30.693877551020407
# 결과: 과체중
#
# 이름 : 카아
# 몸무게: 98
# 키 : 182
# BMI: 29.585798816568044
# 결과: 과체중
#
# 이름 : 아타
# 몸무게: 93
# 키 : 191
# BMI: 25.492722238973712
# 결과: 과체중
#
# 이름 : 다자
# 몸무게: 63
# 키 : 151
# BMI: 27.630367089162757
# 결과: 과체중
#
# 이름 : 하사
# 몸무게: 90
# 키 : 164
# BMI: 33.462224866151104
# 결과: 과체중
#
# 이름 : 파사
# 몸무게: 75
# 키 : 186
# BMI: 21.678806798473808
# 결과: 정상체중
#
# 이름 : 타아
# 몸무게: 56
# 키 : 175
# BMI: 18.285714285714285
# 결과: 저체중
#
# 이름 : 사차
# 몸무게: 58
# 키 : 180
# BMI: 17.901234567901234
# 결과: 저체중
#
# 이름 : 파바
# 몸무게: 67
# 키 : 193
# BMI: 17.9870600553035
# 결과: 저체중
#
# 이름 : 차마
# 몸무게: 70
# 키 : 188
# BMI: 19.805341783612494
# 결과: 정상체중
#
# 이름 : 마카
# 몸무게: 41
# 키 : 145
# BMI: 19.500594530321045
# 결과: 정상체중
#
# 이름 : 타가
# 몸무게: 50
# 키 : 196
# BMI: 13.015410245730946
# 결과: 저체중
#
# 이름 : 아하
# 몸무게: 79
# 키 : 148
# BMI: 36.06647187728269
# 결과: 과체중
#
# 이름 : 나하
# 몸무게: 42
# 키 : 147
# BMI: 19.436345966958214
# 결과: 정상체중
#
# 이름 : 차카
# 몸무게: 88
# 키 : 195
# BMI: 23.14266929651545
# 결과: 정상체중
#
# 이름 : 하타
# 몸무게: 71
# 키 : 175
# BMI: 23.183673469387756
# 결과: 정상체중
#
# 이름 : 나하
# 몸무게: 40
# 키 : 148
# BMI: 18.261504747991236
# 결과: 저체중
#
# 이름 : 하카
# 몸무게: 99
# 키 : 152
# BMI: 42.84972299168975
# 결과: 과체중
#
# 이름 : 하자
# 몸무게: 48
# 키 : 166
# BMI: 17.419073885905068
# 결과: 저체중
#
# 이름 : 자사
# 몸무게: 59
# 키 : 183
# BMI: 17.617725223207618
# 결과: 저체중
#
# 이름 : 하나
# 몸무게: 92
# 키 : 170
# BMI: 31.83391003460208
# 결과: 과체중
#
# 이름 : 아가
# 몸무게: 84
# 키 : 161
# BMI: 32.40615716986227
# 결과: 과체중
#
# 이름 : 하나
# 몸무게: 80
# 키 : 184
# BMI: 23.629489603024574
# 결과: 정상체중
#
# 이름 : 사바
# 몸무게: 91
# 키 : 197
# BMI: 23.448169239094025
# 결과: 정상체중
#
# 이름 : 아아
# 몸무게: 55
# 키 : 162
# BMI: 20.957171162932475
# 결과: 정상체중
#
# 이름 : 자파
# 몸무게: 85
# 키 : 172
# BMI: 28.73174689021093
# 결과: 과체중
#
# 이름 : 차아
# 몸무게: 44
# 키 : 182
# BMI: 13.28341987682647
# 결과: 저체중
#
# 이름 : 라파
# 몸무게: 82
# 키 : 145
# BMI: 39.00118906064209
# 결과: 과체중
#
# 이름 : 나자
# 몸무게: 46
# 키 : 155
# BMI: 19.14672216441207
# 결과: 정상체중
#
# 이름 : 나타
# 몸무게: 49
# 키 : 157
# BMI: 19.879102600511175
# 결과: 정상체중
#
# 이름 : 나사
# 몸무게: 92
# 키 : 140
# BMI: 46.93877551020409
# 결과: 과체중
#
# 이름 : 하자
# 몸무게: 47
# 키 : 159
# BMI: 18.59103674696412
# 결과: 정상체중
#
# 이름 : 가타
# 몸무게: 73
# 키 : 153
# BMI: 31.184587124610193
# 결과: 과체중
#
# 이름 : 파다
# 몸무게: 66
# 키 : 157
# BMI: 26.775934114974238
# 결과: 과체중
#
# 이름 : 파타
# 몸무게: 69
# 키 : 192
# BMI: 18.717447916666668
# 결과: 정상체중
#
# 이름 : 차차
# 몸무게: 74
# 키 : 183
# BMI: 22.096807907073963
# 결과: 정상체중
#
# 이름 : 라카
# 몸무게: 52
# 키 : 158
# BMI: 20.82999519307803
# 결과: 정상체중
#
# 이름 : 카마
# 몸무게: 53
# 키 : 195
# BMI: 13.93819855358317
# 결과: 저체중
#
# 이름 : 가하
# 몸무게: 59
# 키 : 199
# BMI: 14.898613671371935
# 결과: 저체중
#
# 이름 : 하다
# 몸무게: 71
# 키 : 189
# BMI: 19.87626326250665
# 결과: 정상체중
#
# 이름 : 라라
# 몸무게: 66
# 키 : 149
# BMI: 29.72839061303545
# 결과: 과체중
#
# 이름 : 나하
# 몸무게: 79
# 키 : 196
# BMI: 20.564348188254897
# 결과: 정상체중
#
# 이름 : 카하
# 몸무게: 74
# 키 : 175
# BMI: 24.163265306122447
# 결과: 정상체중
#
# 이름 : 아하
# 몸무게: 58
# 키 : 142
# BMI: 28.76413410037691
# 결과: 과체중
#
# 이름 : 가다
# 몸무게: 57
# 키 : 176
# BMI: 18.401342975206614
# 결과: 저체중
#
# 이름 : 마파
# 몸무게: 97
# 키 : 151
# BMI: 42.54199377220297
# 결과: 과체중
#
# 이름 : 라다
# 몸무게: 90
# 키 : 141
# BMI: 45.26935264825713
# 결과: 과체중
#
# 이름 : 파파
# 몸무게: 83
# 키 : 193
# BMI: 22.28247738194314
# 결과: 정상체중
#
# 이름 : 하아
# 몸무게: 65
# 키 : 147
# BMI: 30.080059234578187
# 결과: 과체중
#
# 이름 : 다사
# 몸무게: 71
# 키 : 185
# BMI: 20.74506939371804
# 결과: 정상체중
#
# 이름 : 자차
# 몸무게: 55
# 키 : 184
# BMI: 16.245274102079396
# 결과: 저체중
#
# 이름 : 아가
# 몸무게: 54
# 키 : 161
# BMI: 20.832529609197174
# 결과: 정상체중
#
# 이름 : 마카
# 몸무게: 58
# 키 : 198
# BMI: 14.794408733802674
# 결과: 저체중
#
# 이름 : 나가
# 몸무게: 64
# 키 : 157
# BMI: 25.96454217209623
# 결과: 과체중
#
# 이름 : 가아
# 몸무게: 75
# 키 : 163
# BMI: 28.228386465429637
# 결과: 과체중
#
# 이름 : 카차
# 몸무게: 59
# 키 : 187
# BMI: 16.872086705367607
# 결과: 저체중
#
# 이름 : 다아
# 몸무게: 56
# 키 : 153
# BMI: 23.92242299970097
# 결과: 정상체중
#
# 이름 : 타마
# 몸무게: 97
# 키 : 145
# BMI: 46.13555291319857
# 결과: 과체중
#
# 이름 : 차바
# 몸무게: 80
# 키 : 153
# BMI: 34.17488999957281
# 결과: 과체중
#
# 이름 : 타가
# 몸무게: 51
# 키 : 150
# BMI: 22.666666666666668
# 결과: 정상체중
#
# 이름 : 바마
# 몸무게: 63
# 키 : 144
# BMI: 30.381944444444446
# 결과: 과체중
#
# 이름 : 자라
# 몸무게: 74
# 키 : 159
# BMI: 29.270994027135
# 결과: 과체중
#
# 이름 : 하마
# 몸무게: 62
# 키 : 154
# BMI: 26.14268848035082
# 결과: 과체중
#
# 이름 : 라하
# 몸무게: 53
# 키 : 145
# BMI: 25.20808561236623
# 결과: 과체중
#
# 이름 : 자나
# 몸무게: 43
# 키 : 172
# BMI: 14.534883720930234
# 결과: 저체중
#
# 이름 : 사차
# 몸무게: 95
# 키 : 186
# BMI: 27.45982194473349
# 결과: 과체중
#
# 이름 : 바마
# 몸무게: 76
# 키 : 167
# BMI: 27.250887446663558
# 결과: 과체중
#
# 이름 : 나가
# 몸무게: 60
# 키 : 189
# BMI: 16.79684219366759
# 결과: 저체중
#
# 이름 : 타다
# 몸무게: 55
# 키 : 164
# BMI: 20.449137418203453
# 결과: 정상체중
#
# 이름 : 가가
# 몸무게: 64
# 키 : 159
# BMI: 25.315454293738377
# 결과: 과체중
#
# 이름 : 차나
# 몸무게: 75
# 키 : 170
# BMI: 25.95155709342561
# 결과: 과체중
#
# 이름 : 아사
# 몸무게: 68
# 키 : 181
# BMI: 20.756387167668876
# 결과: 정상체중
#
# 이름 : 라사
# 몸무게: 89
# 키 : 175
# BMI: 29.06122448979592
# 결과: 과체중
#
# 이름 : 아바
# 몸무게: 57
# 키 : 183
# BMI: 17.020514198692105
# 결과: 저체중
#
# 이름 : 가다
# 몸무게: 50
# 키 : 159
# BMI: 19.77769866698311
# 결과: 정상체중
#
# 이름 : 차하
# 몸무게: 98
# 키 : 172
# BMI: 33.12601406165495
# 결과: 과체중
#
# 이름 : 다바
# 몸무게: 89
# 키 : 174
# BMI: 29.396221429515126
# 결과: 과체중
#
# 이름 : 파하
# 몸무게: 67
# 키 : 147
# BMI: 31.005599518719055
# 결과: 과체중
#
# 이름 : 자나
# 몸무게: 91
# 키 : 198
# BMI: 23.21191715131109
# 결과: 정상체중
#
# 이름 : 다가
# 몸무게: 60
# 키 : 173
# BMI: 20.04744562130375
# 결과: 정상체중
#
# 이름 : 사파
# 몸무게: 94
# 키 : 196
# BMI: 24.46897126197418
# 결과: 정상체중
#
# 이름 : 가사
# 몸무게: 45
# 키 : 188
# BMI: 12.73200543232232
# 결과: 저체중
#
# 이름 : 차하
# 몸무게: 57
# 키 : 159
# BMI: 22.54657648036074
# 결과: 정상체중
#
# 이름 : 가카
# 몸무게: 52
# 키 : 193
# BMI: 13.960106311578835
# 결과: 저체중
#
# 이름 : 사바
# 몸무게: 86
# 키 : 185
# BMI: 25.127830533235937
# 결과: 과체중
#
# 이름 : 사라
# 몸무게: 72
# 키 : 171
# BMI: 24.622960911049557
# 결과: 정상체중
#
# 이름 : 차파
# 몸무게: 43
# 키 : 188
# BMI: 12.166138524219104
# 결과: 저체중
#
# 이름 : 사자
# 몸무게: 98
# 키 : 185
# BMI: 28.634039444850252
# 결과: 과체중
#
# 이름 : 마차
# 몸무게: 44
# 키 : 149
# BMI: 19.818927075356967
# 결과: 정상체중
#
# 이름 : 바하
# 몸무게: 66
# 키 : 185
# BMI: 19.284149013878743
# 결과: 정상체중
#
# 이름 : 마카
# 몸무게: 62
# 키 : 162
# BMI: 23.624447492760247
# 결과: 정상체중
#
# 이름 : 아나
# 몸무게: 80
# 키 : 184
# BMI: 23.629489603024574
# 결과: 정상체중
#
# 이름 : 자사
# 몸무게: 44
# 키 : 175
# BMI: 14.36734693877551
# 결과: 저체중
#
# 이름 : 다나
# 몸무게: 92
# 키 : 188
# BMI: 26.029877772747852
# 결과: 과체중
#
# 이름 : 차라
# 몸무게: 50
# 키 : 189
# BMI: 13.997368494722993
# 결과: 저체중
#
# 이름 : 다나
# 몸무게: 42
# 키 : 195
# BMI: 11.045364891518739
# 결과: 저체중
#
# 이름 : 바카
# 몸무게: 84
# 키 : 185
# BMI: 24.543462381300216
# 결과: 정상체중
#
# 이름 : 타자
# 몸무게: 71
# 키 : 166
# BMI: 25.76571345623458
# 결과: 과체중
#
# 이름 : 가바
# 몸무게: 99
# 키 : 175
# BMI: 32.326530612244895
# 결과: 과체중
#
# 이름 : 하사
# 몸무게: 58
# 키 : 173
# BMI: 19.37919743392696
# 결과: 정상체중
#
# 이름 : 타라
# 몸무게: 86
# 키 : 141
# BMI: 43.25738141944571
# 결과: 과체중
#
# 이름 : 가하
# 몸무게: 43
# 키 : 167
# BMI: 15.418265265875435
# 결과: 저체중
#
# 이름 : 자라
# 몸무게: 74
# 키 : 190
# BMI: 20.498614958448755
# 결과: 정상체중
#
# 이름 : 카파
# 몸무게: 72
# 키 : 144
# BMI: 34.72222222222222
# 결과: 과체중
#
# 이름 : 가차
# 몸무게: 97
# 키 : 184
# BMI: 28.650756143667294
# 결과: 과체중
#
# 이름 : 파라
# 몸무게: 78
# 키 : 188
# BMI: 22.068809416025353
# 결과: 정상체중
#
# 이름 : 마라
# 몸무게: 57
# 키 : 140
# BMI: 29.081632653061227
# 결과: 과체중
#
# 이름 : 가나
# 몸무게: 61
# 키 : 166
# BMI: 22.136739730004358
# 결과: 정상체중
#
# 이름 : 카사
# 몸무게: 73
# 키 : 179
# BMI: 22.783308885490467
# 결과: 정상체중
#
# 이름 : 파아
# 몸무게: 68
# 키 : 156
# BMI: 27.94214332675871
# 결과: 과체중
#
# 이름 : 아마
# 몸무게: 60
# 키 : 180
# BMI: 18.51851851851852
# 결과: 정상체중
#
# 이름 : 아라
# 몸무게: 87
# 키 : 155
# BMI: 36.21227887617065
# 결과: 과체중
#
# 이름 : 바다
# 몸무게: 69
# 키 : 143
# BMI: 33.74248129492885
# 결과: 과체중
#
# 이름 : 가하
# 몸무게: 58
# 키 : 186
# BMI: 16.76494392415308
# 결과: 저체중
#
# 이름 : 가나
# 몸무게: 57
# 키 : 170
# BMI: 19.723183391003463
# 결과: 정상체중
#
# 이름 : 나가
# 몸무게: 60
# 키 : 169
# BMI: 21.007667798746546
# 결과: 정상체중
#
# 이름 : 타차
# 몸무게: 56
# 키 : 172
# BMI: 18.92915089237426
# 결과: 정상체중
#
# 이름 : 바아
# 몸무게: 44
# 키 : 144
# BMI: 21.219135802469136
# 결과: 정상체중
#
# 이름 : 하나
# 몸무게: 66
# 키 : 143
# BMI: 32.27541689080151
# 결과: 과체중
#
# 이름 : 다사
# 몸무게: 91
# 키 : 173
# BMI: 30.405292525644022
# 결과: 과체중
#
# 이름 : 가카
# 몸무게: 56
# 키 : 162
# BMI: 21.338210638622158
# 결과: 정상체중
#
# 이름 : 마가
# 몸무게: 41
# 키 : 143
# BMI: 20.049880189740332
# 결과: 정상체중
#
# 이름 : 하바
# 몸무게: 77
# 키 : 191
# BMI: 21.106877552698666
# 결과: 정상체중
#
# 이름 : 아사
# 몸무게: 83
# 키 : 196
# BMI: 21.605581007913372
# 결과: 정상체중
#
# 이름 : 나가
# 몸무게: 67
# 키 : 168
# BMI: 23.738662131519277
# 결과: 정상체중
#
# 이름 : 파가
# 몸무게: 60
# 키 : 195
# BMI: 15.779092702169626
# 결과: 저체중
#
# 이름 : 자바
# 몸무게: 99
# 키 : 197
# BMI: 25.509546754618775
# 결과: 과체중
#
# 이름 : 타차
# 몸무게: 61
# 키 : 169
# BMI: 21.35779559539232
# 결과: 정상체중
#
# 이름 : 차아
# 몸무게: 92
# 키 : 184
# BMI: 27.173913043478258
# 결과: 과체중
#
# 이름 : 파바
# 몸무게: 52
# 키 : 170
# BMI: 17.99307958477509
# 결과: 저체중
#
# 이름 : 다가
# 몸무게: 74
# 키 : 178
# BMI: 23.355636914530994
# 결과: 정상체중
#
# 이름 : 하다
# 몸무게: 74
# 키 : 194
# BMI: 19.66202572005527
# 결과: 정상체중
#
# 이름 : 마하
# 몸무게: 82
# 키 : 144
# BMI: 39.54475308641975
# 결과: 과체중
#
# 이름 : 카타
# 몸무게: 56
# 키 : 195
# BMI: 14.72715318869165
# 결과: 저체중
#
# 이름 : 다마
# 몸무게: 47
# 키 : 161
# BMI: 18.132016511708652
# 결과: 저체중
#
# 이름 : 하라
# 몸무게: 70
# 키 : 146
# BMI: 32.839181835241135
# 결과: 과체중
#
# 이름 : 파라
# 몸무게: 59
# 키 : 164
# BMI: 21.936347412254616
# 결과: 정상체중
#
# 이름 : 마라
# 몸무게: 67
# 키 : 171
# BMI: 22.91303307000445
# 결과: 정상체중
#
# 이름 : 가타
# 몸무게: 82
# 키 : 148
# BMI: 37.43608473338203
# 결과: 과체중
#
# 이름 : 카자
# 몸무게: 44
# 키 : 165
# BMI: 16.161616161616163
# 결과: 저체중
#
# 이름 : 아마
# 몸무게: 41
# 키 : 187
# BMI: 11.724670422374102
# 결과: 저체중
#
# 이름 : 자다
# 몸무게: 72
# 키 : 164
# BMI: 26.769779892920884
# 결과: 과체중
#
# 이름 : 다바
# 몸무게: 61
# 키 : 196
# BMI: 15.878800499791755
# 결과: 저체중
#
# 이름 : 바마
# 몸무게: 66
# 키 : 179
# BMI: 20.598608033457133
# 결과: 정상체중
#
# 이름 : 타나
# 몸무게: 61
# 키 : 174
# BMI: 20.147971991015986
# 결과: 정상체중
#
# 이름 : 마사
# 몸무게: 71
# 키 : 155
# BMI: 29.552549427679498
# 결과: 과체중
#
# 이름 : 사타
# 몸무게: 99
# 키 : 179
# BMI: 30.8979120501857
# 결과: 과체중
#
# 이름 : 카자
# 몸무게: 79
# 키 : 197
# BMI: 20.3561029658069
# 결과: 정상체중
#
# 이름 : 라하
# 몸무게: 47
# 키 : 162
# BMI: 17.908855357415025
# 결과: 저체중
#
# 이름 : 마라
# 몸무게: 98
# 키 : 199
# BMI: 24.74684982702457
# 결과: 정상체중
#
# 이름 : 다사
# 몸무게: 96
# 키 : 153
# BMI: 41.009867999487376
# 결과: 과체중
#
# 이름 : 다하
# 몸무게: 90
# 키 : 171
# BMI: 30.778701138811947
# 결과: 과체중
#
# 이름 : 카하
# 몸무게: 44
# 키 : 156
# BMI: 18.080210387902692
# 결과: 저체중
#
# 이름 : 자아
# 몸무게: 61
# 키 : 187
# BMI: 17.444021847922443
# 결과: 저체중
#
# 이름 : 사타
# 몸무게: 70
# 키 : 173
# BMI: 23.38868655818771
# 결과: 정상체중
#
# 이름 : 나타
# 몸무게: 87
# 키 : 143
# BMI: 42.5448677196929
# 결과: 과체중
#
# 이름 : 하자
# 몸무게: 76
# 키 : 190
# BMI: 21.05263157894737
# 결과: 정상체중
#
# 이름 : 라마
# 몸무게: 99
# 키 : 141
# BMI: 49.79628791308285
# 결과: 과체중
#
# 이름 : 타가
# 몸무게: 53
# 키 : 163
# BMI: 19.94805976890361
# 결과: 정상체중
#
# 이름 : 차타
# 몸무게: 40
# 키 : 149
# BMI: 18.017206432142697
# 결과: 저체중
#
# 이름 : 바사
# 몸무게: 54
# 키 : 152
# BMI: 23.372576177285318
# 결과: 정상체중
#
# 이름 : 마파
# 몸무게: 78
# 키 : 181
# BMI: 23.808797045267237
# 결과: 정상체중
#
# 이름 : 나가
# 몸무게: 51
# 키 : 169
# BMI: 17.856517628934565
# 결과: 저체중
#
# 이름 : 사자
# 몸무게: 73
# 키 : 165
# BMI: 26.813590449954088
# 결과: 과체중
#
# 이름 : 사아
# 몸무게: 63
# 키 : 189
# BMI: 17.63668430335097
# 결과: 저체중
#
# 이름 : 카마
# 몸무게: 75
# 키 : 161
# BMI: 28.93406890166274
# 결과: 과체중
#
# 이름 : 하사
# 몸무게: 67
# 키 : 198
# BMI: 17.090092847668604
# 결과: 저체중
#
# 이름 : 바차
# 몸무게: 58
# 키 : 155
# BMI: 24.141519250780433
# 결과: 정상체중
#
# 이름 : 나파
# 몸무게: 61
# 키 : 176
# BMI: 19.692665289256198
# 결과: 정상체중
#
# 이름 : 차파
# 몸무게: 63
# 키 : 160
# BMI: 24.609374999999996
# 결과: 정상체중
#
# 이름 : 자타
# 몸무게: 98
# 키 : 196
# BMI: 25.510204081632654
# 결과: 과체중
#
# 이름 : 가차
# 몸무게: 61
# 키 : 193
# BMI: 16.376278557813635
# 결과: 저체중
#
# 이름 : 바가
# 몸무게: 96
# 키 : 157
# BMI: 38.946813258144346
# 결과: 과체중
#
# 이름 : 마바
# 몸무게: 86
# 키 : 150
# BMI: 38.22222222222222
# 결과: 과체중
#
# 이름 : 바파
# 몸무게: 57
# 키 : 143
# BMI: 27.874223678419487
# 결과: 과체중
#
# 이름 : 하나
# 몸무게: 79
# 키 : 150
# BMI: 35.111111111111114
# 결과: 과체중
#
# 이름 : 마나
# 몸무게: 87
# 키 : 152
# BMI: 37.655817174515235
# 결과: 과체중
#
# 이름 : 라타
# 몸무게: 92
# 키 : 143
# BMI: 44.989975059905134
# 결과: 과체중
#
# 이름 : 나다
# 몸무게: 54
# 키 : 159
# BMI: 21.359914560341757
# 결과: 정상체중
#
# 이름 : 다파
# 몸무게: 79
# 키 : 192
# BMI: 21.43012152777778
# 결과: 정상체중
#
# 이름 : 가파
# 몸무게: 57
# 키 : 179
# BMI: 17.789706937985706
# 결과: 저체중
#
# 이름 : 사카
# 몸무게: 58
# 키 : 150
# BMI: 25.77777777777778
# 결과: 과체중
#
# 이름 : 카타
# 몸무게: 83
# 키 : 145
# BMI: 39.47681331747919
# 결과: 과체중
#
# 이름 : 자가
# 몸무게: 52
# 키 : 187
# BMI: 14.870313706425689
# 결과: 저체중
#
# 이름 : 차다
# 몸무게: 42
# 키 : 173
# BMI: 14.033211934912625
# 결과: 저체중
#
# 이름 : 타차
# 몸무게: 99
# 키 : 140
# BMI: 50.51020408163266
# 결과: 과체중
#
# 이름 : 다바
# 몸무게: 49
# 키 : 164
# BMI: 18.218322427126715
# 결과: 저체중
#
# 이름 : 차바
# 몸무게: 83
# 키 : 166
# BMI: 30.120481927710845
# 결과: 과체중
#
# 이름 : 라아
# 몸무게: 46
# 키 : 145
# BMI: 21.87871581450654
# 결과: 정상체중
#
# 이름 : 마타
# 몸무게: 99
# 키 : 164
# BMI: 36.808447352766215
# 결과: 과체중
#
# 이름 : 다하
# 몸무게: 67
# 키 : 195
# BMI: 17.61998685075608
# 결과: 저체중
#
# 이름 : 가차
# 몸무게: 71
# 키 : 159
# BMI: 28.084332107116012
# 결과: 과체중
#
# 이름 : 가아
# 몸무게: 59
# 키 : 199
# BMI: 14.898613671371935
# 결과: 저체중
#
# 이름 : 바다
# 몸무게: 70
# 키 : 146
# BMI: 32.839181835241135
# 결과: 과체중
#
# 이름 : 타파
# 몸무게: 44
# 키 : 191
# BMI: 12.06107288725638
# 결과: 저체중
#
# 이름 : 가바
# 몸무게: 88
# 키 : 168
# BMI: 31.17913832199547
# 결과: 과체중
#
# 이름 : 파아
# 몸무게: 50
# 키 : 185
# BMI: 14.609203798392986
# 결과: 저체중
#
# 이름 : 마아
# 몸무게: 82
# 키 : 150
# BMI: 36.44444444444444
# 결과: 과체중
#
# 이름 : 나카
# 몸무게: 97
# 키 : 145
# BMI: 46.13555291319857
# 결과: 과체중
#
# 이름 : 마카
# 몸무게: 48
# 키 : 170
# BMI: 16.60899653979239
# 결과: 저체중
#
# 이름 : 하가
# 몸무게: 54
# 키 : 159
# BMI: 21.359914560341757
# 결과: 정상체중
#
# 이름 : 마아
# 몸무게: 72
# 키 : 183
# BMI: 21.49959688255845
# 결과: 정상체중
#
# 이름 : 바바
# 몸무게: 92
# 키 : 181
# BMI: 28.082170873904946
# 결과: 과체중
#
# 이름 : 차자
# 몸무게: 46
# 키 : 175
# BMI: 15.020408163265307
# 결과: 저체중
#
# 이름 : 자바
# 몸무게: 91
# 키 : 185
# BMI: 26.588750913075234
# 결과: 과체중
#
# 이름 : 가차
# 몸무게: 49
# 키 : 156
# BMI: 20.134779750164363
# 결과: 정상체중
#
# 이름 : 다차
# 몸무게: 40
# 키 : 185
# BMI: 11.68736303871439
# 결과: 저체중
#
# 이름 : 아다
# 몸무게: 93
# 키 : 160
# BMI: 36.32812499999999
# 결과: 과체중
#
# 이름 : 다차
# 몸무게: 46
# 키 : 175
# BMI: 15.020408163265307
# 결과: 저체중
#
# 이름 : 바타
# 몸무게: 45
# 키 : 169
# BMI: 15.75575084905991
# 결과: 저체중
#
# 이름 : 아라
# 몸무게: 92
# 키 : 196
# BMI: 23.94835485214494
# 결과: 정상체중
#
# 이름 : 자바
# 몸무게: 57
# 키 : 197
# BMI: 14.687314798113839
# 결과: 저체중
#
# 이름 : 사라
# 몸무게: 76
# 키 : 180
# BMI: 23.456790123456788
# 결과: 정상체중
#
# 이름 : 라차
# 몸무게: 85
# 키 : 171
# BMI: 29.06877329776684
# 결과: 과체중
#
# 이름 : 카바
# 몸무게: 40
# 키 : 182
# BMI: 12.075836251660427
# 결과: 저체중
#
# 이름 : 아자
# 몸무게: 43
# 키 : 174
# BMI: 14.202668780552253
# 결과: 저체중
#
# 이름 : 자하
# 몸무게: 79
# 키 : 158
# BMI: 31.64556962025316
# 결과: 과체중
#
# 이름 : 다나
# 몸무게: 76
# 키 : 166
# BMI: 27.58020031934969
# 결과: 과체중
#
# 이름 : 하나
# 몸무게: 68
# 키 : 183
# BMI: 20.305174833527424
# 결과: 정상체중
#
# 이름 : 아차
# 몸무게: 45
# 키 : 182
# BMI: 13.58531578311798
# 결과: 저체중
#
# 이름 : 나사
# 몸무게: 87
# 키 : 170
# BMI: 30.103806228373706
# 결과: 과체중
#
# 이름 : 다자
# 몸무게: 83
# 키 : 156
# BMI: 34.10585141354372
# 결과: 과체중
#
# 이름 : 하파
# 몸무게: 43
# 키 : 195
# BMI: 11.308349769888233
# 결과: 저체중
#
# 이름 : 바사
# 몸무게: 92
# 키 : 170
# BMI: 31.83391003460208
# 결과: 과체중
#
# 이름 : 마하
# 몸무게: 90
# 키 : 182
# BMI: 27.17063156623596
# 결과: 과체중
#
# 이름 : 나자
# 몸무게: 43
# 키 : 199
# BMI: 10.858311658796495
# 결과: 저체중
#
# 이름 : 나마
# 몸무게: 48
# 키 : 184
# BMI: 14.177693761814744
# 결과: 저체중
#
# 이름 : 카차
# 몸무게: 75
# 키 : 186
# BMI: 21.678806798473808
# 결과: 정상체중
#
# 이름 : 라차
# 몸무게: 93
# 키 : 183
# BMI: 27.77031263997133
# 결과: 과체중
#
# 이름 : 나차
# 몸무게: 97
# 키 : 199
# BMI: 24.494330951238602
# 결과: 정상체중
#
# 이름 : 하라
# 몸무게: 70
# 키 : 165
# BMI: 25.71166207529844
# 결과: 과체중
#
# 이름 : 카사
# 몸무게: 71
# 키 : 154
# BMI: 29.93759487265981
# 결과: 과체중
#
# 이름 : 카마
# 몸무게: 97
# 키 : 147
# BMI: 44.88870378083207
# 결과: 과체중
#
# 이름 : 바다
# 몸무게: 71
# 키 : 158
# BMI: 28.44095497516423
# 결과: 과체중
#
# 이름 : 하카
# 몸무게: 94
# 키 : 177
# BMI: 30.00414951003862
# 결과: 과체중
#
# 이름 : 타다
# 몸무게: 84
# 키 : 159
# BMI: 33.22653376053162
# 결과: 과체중
#
# 이름 : 바파
# 몸무게: 59
# 키 : 145
# BMI: 28.061831153388823
# 결과: 과체중
#
# 이름 : 자라
# 몸무게: 45
# 키 : 160
# BMI: 17.578124999999996
# 결과: 저체중
#
# 이름 : 카자
# 몸무게: 65
# 키 : 180
# BMI: 20.061728395061728
# 결과: 정상체중
#
# 이름 : 나나
# 몸무게: 93
# 키 : 183
# BMI: 27.77031263997133
# 결과: 과체중
#
# 이름 : 라마
# 몸무게: 71
# 키 : 185
# BMI: 20.74506939371804
# 결과: 정상체중
#
# 이름 : 라가
# 몸무게: 42
# 키 : 184
# BMI: 12.4054820415879
# 결과: 저체중
#
# 이름 : 차가
# 몸무게: 48
# 키 : 162
# BMI: 18.289894833104707
# 결과: 저체중
#
# 이름 : 파자
# 몸무게: 89
# 키 : 179
# BMI: 27.776910832995224
# 결과: 과체중
#
# 이름 : 하나
# 몸무게: 57
# 키 : 175
# BMI: 18.612244897959183
# 결과: 정상체중
#
# 이름 : 차타
# 몸무게: 50
# 키 : 167
# BMI: 17.92821542543655
# 결과: 저체중
#
# 이름 : 바타
# 몸무게: 90
# 키 : 180
# BMI: 27.777777777777775
# 결과: 과체중
#
# 이름 : 라카
# 몸무게: 87
# 키 : 151
# BMI: 38.15622121836761
# 결과: 과체중
#
# 이름 : 다파
# 몸무게: 91
# 키 : 178
# BMI: 28.721121070571897
# 결과: 과체중
#
# 이름 : 자사
# 몸무게: 87
# 키 : 156
# BMI: 35.74950690335305
# 결과: 과체중
#
# 이름 : 자바
# 몸무게: 75
# 키 : 192
# BMI: 20.345052083333332
# 결과: 정상체중
#
# 이름 : 라카
# 몸무게: 59
# 키 : 192
# BMI: 16.004774305555557
# 결과: 저체중
#
# 이름 : 라나
# 몸무게: 93
# 키 : 180
# BMI: 28.703703703703702
# 결과: 과체중
#
# 이름 : 하파
# 몸무게: 84
# 키 : 182
# BMI: 25.359256128486894
# 결과: 과체중
#
# 이름 : 하아
# 몸무게: 90
# 키 : 161
# BMI: 34.72088268199529
# 결과: 과체중
#
# 이름 : 가바
# 몸무게: 84
# 키 : 191
# BMI: 23.025684602944
# 결과: 정상체중
#
# 이름 : 타카
# 몸무게: 86
# 키 : 172
# BMI: 29.069767441860467
# 결과: 과체중
#
# 이름 : 파카
# 몸무게: 99
# 키 : 163
# BMI: 37.26147013436712
# 결과: 과체중
#
# 이름 : 나아
# 몸무게: 62
# 키 : 172
# BMI: 20.9572742022715
# 결과: 정상체중
#
# 이름 : 나카
# 몸무게: 76
# 키 : 140
# BMI: 38.77551020408164
# 결과: 과체중
#
# 이름 : 라타
# 몸무게: 82
# 키 : 185
# BMI: 23.959094229364496
# 결과: 정상체중
#
# 이름 : 자타
# 몸무게: 60
# 키 : 174
# BMI: 19.817677368212443
# 결과: 정상체중
#
# 이름 : 차차
# 몸무게: 89
# 키 : 167
# BMI: 31.912223457277065
# 결과: 과체중
#
# 이름 : 카바
# 몸무게: 93
# 키 : 197
# BMI: 23.963513617975213
# 결과: 정상체중
#
# 이름 : 마라
# 몸무게: 90
# 키 : 157
# BMI: 36.51263742951032
# 결과: 과체중
#
# 이름 : 바라
# 몸무게: 55
# 키 : 167
# BMI: 19.721036967980208
# 결과: 정상체중
#
# 이름 : 나라
# 몸무게: 91
# 키 : 153
# BMI: 38.87393737451408
# 결과: 과체중
#
# 이름 : 사카
# 몸무게: 60
# 키 : 143
# BMI: 29.34128808254683
# 결과: 과체중
#
# 이름 : 라아
# 몸무게: 99
# 키 : 149
# BMI: 44.59258591955317
# 결과: 과체중
#
# 이름 : 바카
# 몸무게: 54
# 키 : 186
# BMI: 15.608740894901143
# 결과: 저체중
#
# 이름 : 하하
# 몸무게: 44
# 키 : 158
# BMI: 17.625380547989103
# 결과: 저체중
#
# 이름 : 파차
# 몸무게: 63
# 키 : 146
# BMI: 29.555263651717024
# 결과: 과체중
#
# 이름 : 아자
# 몸무게: 45
# 키 : 174
# BMI: 14.863258026159334
# 결과: 저체중
#
# 이름 : 차마
# 몸무게: 85
# 키 : 161
# BMI: 32.79194475521777
# 결과: 과체중
#
# 이름 : 다자
# 몸무게: 80
# 키 : 195
# BMI: 21.038790269559502
# 결과: 정상체중
#
# 이름 : 가라
# 몸무게: 42
# 키 : 150
# BMI: 18.666666666666668
# 결과: 정상체중
#
# 이름 : 다자
# 몸무게: 59
# 키 : 199
# BMI: 14.898613671371935
# 결과: 저체중
#
# 이름 : 아다
# 몸무게: 53
# 키 : 182
# BMI: 16.000483033450067
# 결과: 저체중
#
# 이름 : 마하
# 몸무게: 41
# 키 : 145
# BMI: 19.500594530321045
# 결과: 정상체중
#
# 이름 : 가바
# 몸무게: 91
# 키 : 168
# BMI: 32.242063492063494
# 결과: 과체중
#
# 이름 : 아바
# 몸무게: 79
# 키 : 175
# BMI: 25.79591836734694
# 결과: 과체중
#
# 이름 : 아카
# 몸무게: 55
# 키 : 191
# BMI: 15.076341109070475
# 결과: 저체중
#
# 이름 : 사사
# 몸무게: 85
# 키 : 170
# BMI: 29.411764705882355
# 결과: 과체중
#
# 이름 : 카아
# 몸무게: 50
# 키 : 146
# BMI: 23.45655845374367
# 결과: 정상체중
#
# 이름 : 마라
# 몸무게: 55
# 키 : 171
# BMI: 18.80920625149619
# 결과: 정상체중
#
# 이름 : 다차
# 몸무게: 90
# 키 : 197
# BMI: 23.19049704965343
# 결과: 정상체중
#
# 이름 : 사파
# 몸무게: 82
# 키 : 147
# BMI: 37.94715164977556
# 결과: 과체중
#
# 이름 : 사라
# 몸무게: 50
# 키 : 188
# BMI: 14.146672702580354
# 결과: 저체중
#
# 이름 : 라차
# 몸무게: 94
# 키 : 185
# BMI: 27.465303140978815
# 결과: 과체중
#
# 이름 : 사카
# 몸무게: 45
# 키 : 189
# BMI: 12.597631645250694
# 결과: 저체중
#
# 이름 : 사사
# 몸무게: 60
# 키 : 143
# BMI: 29.34128808254683
# 결과: 과체중
#
# 이름 : 마가
# 몸무게: 69
# 키 : 148
# BMI: 31.50109569028488
# 결과: 과체중
#
# 이름 : 아마
# 몸무게: 48
# 키 : 199
# BMI: 12.12090603772632
# 결과: 저체중
#
# 이름 : 라자
# 몸무게: 53
# 키 : 157
# BMI: 21.50188648626719
# 결과: 정상체중
#
# 이름 : 타타
# 몸무게: 59
# 키 : 177
# BMI: 18.832391713747644
# 결과: 정상체중
#
# 이름 : 하바
# 몸무게: 79
# 키 : 150
# BMI: 35.111111111111114
# 결과: 과체중
#
# 이름 : 하바
# 몸무게: 47
# 키 : 167
# BMI: 16.85252249991036
# 결과: 저체중
#
# 이름 : 자가
# 몸무게: 66
# 키 : 183
# BMI: 19.70796380901191
# 결과: 정상체중
#
# 이름 : 마카
# 몸무게: 78
# 키 : 166
# BMI: 28.305995064595734
# 결과: 과체중
#
# 이름 : 다가
# 몸무게: 43
# 키 : 141
# BMI: 21.628690709722854
# 결과: 정상체중
#
# 이름 : 하아
# 몸무게: 80
# 키 : 161
# BMI: 30.86300682844026
# 결과: 과체중
#
# 이름 : 나타
# 몸무게: 83
# 키 : 175
# BMI: 27.102040816326532
# 결과: 과체중
#
# 이름 : 타타
# 몸무게: 58
# 키 : 159
# BMI: 22.942130453700404
# 결과: 정상체중
#
# 이름 : 마마
# 몸무게: 55
# 키 : 197
# BMI: 14.171970419232652
# 결과: 저체중
#
# 이름 : 바사
# 몸무게: 65
# 키 : 164
# BMI: 24.167162403331353
# 결과: 정상체중
#
# 이름 : 파자
# 몸무게: 69
# 키 : 185
# BMI: 20.16070124178232
# 결과: 정상체중
#
# 이름 : 타파
# 몸무게: 78
# 키 : 160
# BMI: 30.468749999999993
# 결과: 과체중
#
# 이름 : 다마
# 몸무게: 77
# 키 : 161
# BMI: 29.705644072373747
# 결과: 과체중
#
# 이름 : 타바
# 몸무게: 53
# 키 : 192
# BMI: 14.37717013888889
# 결과: 저체중
#
# 이름 : 자마
# 몸무게: 52
# 키 : 195
# BMI: 13.675213675213676
# 결과: 저체중
#
# 이름 : 타가
# 몸무게: 67
# 키 : 147
# BMI: 31.005599518719055
# 결과: 과체중
#
# 이름 : 다가
# 몸무게: 90
# 키 : 169
# BMI: 31.51150169811982
# 결과: 과체중
#
# 이름 : 라라
# 몸무게: 64
# 키 : 182
# BMI: 19.32133800265668
# 결과: 정상체중
#
# 이름 : 라라
# 몸무게: 49
# 키 : 145
# BMI: 23.305588585017837
# 결과: 정상체중
#
# 이름 : 차사
# 몸무게: 79
# 키 : 166
# BMI: 28.668892437218755
# 결과: 과체중
#
# 이름 : 바라
# 몸무게: 53
# 키 : 179
# BMI: 16.541306451109516
# 결과: 저체중
#
# 이름 : 마나
# 몸무게: 84
# 키 : 183
# BMI: 25.082863029651524
# 결과: 과체중
#
# 이름 : 마자
# 몸무게: 69
# 키 : 148
# BMI: 31.50109569028488
# 결과: 과체중
#
# 이름 : 다하
# 몸무게: 40
# 키 : 179
# BMI: 12.484004868761899
# 결과: 저체중
#
# 이름 : 타하
# 몸무게: 71
# 키 : 195
# BMI: 18.671926364234057
# 결과: 정상체중
#
# 이름 : 차가
# 몸무게: 81
# 키 : 182
# BMI: 24.453568409612362
# 결과: 정상체중
#
# 이름 : 파바
# 몸무게: 76
# 키 : 163
# BMI: 28.604764951635367
# 결과: 과체중
#
# 이름 : 하파
# 몸무게: 52
# 키 : 142
# BMI: 25.788534021027573
# 결과: 과체중
#
# 이름 : 바나
# 몸무게: 72
# 키 : 178
# BMI: 22.724403484408533
# 결과: 정상체중
#
# 이름 : 타타
# 몸무게: 91
# 키 : 175
# BMI: 29.714285714285715
# 결과: 과체중
#
# 이름 : 하바
# 몸무게: 64
# 키 : 180
# BMI: 19.753086419753085
# 결과: 정상체중
#
# 이름 : 마바
# 몸무게: 85
# 키 : 160
# BMI: 33.20312499999999
# 결과: 과체중
#
# 이름 : 사차
# 몸무게: 66
# 키 : 145
# BMI: 31.391200951248514
# 결과: 과체중
#
# 이름 : 자카
# 몸무게: 86
# 키 : 148
# BMI: 39.26223520818115
# 결과: 과체중
#
# 이름 : 나아
# 몸무게: 79
# 키 : 160
# BMI: 30.859374999999993
# 결과: 과체중
#
# 이름 : 나파
# 몸무게: 42
# 키 : 190
# BMI: 11.634349030470915
# 결과: 저체중
#
# 이름 : 하카
# 몸무게: 70
# 키 : 169
# BMI: 24.508945765204302
# 결과: 정상체중
#
# 이름 : 하카
# 몸무게: 73
# 키 : 191
# BMI: 20.010416381129904
# 결과: 정상체중
#
# 이름 : 마라
# 몸무게: 98
# 키 : 173
# BMI: 32.74416118146279
# 결과: 과체중
#
# 이름 : 사나
# 몸무게: 82
# 키 : 169
# BMI: 28.71047932495361
# 결과: 과체중
#
# 이름 : 다사
# 몸무게: 43
# 키 : 166
# BMI: 15.604587022789955
# 결과: 저체중
#
# 이름 : 나타
# 몸무게: 89
# 키 : 196
# BMI: 23.167430237401085
# 결과: 정상체중
#
# 이름 : 타가
# 몸무게: 55
# 키 : 177
# BMI: 17.555619394171533
# 결과: 저체중
#
# 이름 : 하아
# 몸무게: 67
# 키 : 166
# BMI: 24.31412396574249
# 결과: 정상체중
#
# 이름 : 파하
# 몸무게: 41
# 키 : 166
# BMI: 14.878792277543912
# 결과: 저체중
#
# 이름 : 마다
# 몸무게: 85
# 키 : 182
# BMI: 25.661152034778407
# 결과: 과체중
#
# 이름 : 하라
# 몸무게: 88
# 키 : 151
# BMI: 38.59479847375115
# 결과: 과체중
#
# 이름 : 하나
# 몸무게: 99
# 키 : 192
# BMI: 26.85546875
# 결과: 과체중
#
# 이름 : 바나
# 몸무게: 86
# 키 : 189
# BMI: 24.075473810923548
# 결과: 정상체중
#
# 이름 : 사나
# 몸무게: 84
# 키 : 168
# BMI: 29.761904761904766
# 결과: 과체중
#
# 이름 : 타파
# 몸무게: 86
# 키 : 192
# BMI: 23.328993055555557
# 결과: 정상체중
#
# 이름 : 마마
# 몸무게: 90
# 키 : 181
# BMI: 27.471688898385274
# 결과: 과체중
#
# 이름 : 바하
# 몸무게: 56
# 키 : 156
# BMI: 23.011176857330703
# 결과: 정상체중
#
# 이름 : 자아
# 몸무게: 94
# 키 : 175
# BMI: 30.693877551020407
# 결과: 과체중
#
# 이름 : 나카
# 몸무게: 47
# 키 : 185
# BMI: 13.732651570489407
# 결과: 저체중
#
# 이름 : 가라
# 몸무게: 87
# 키 : 167
# BMI: 31.1950948402596
# 결과: 과체중
#
# 이름 : 카나
# 몸무게: 97
# 키 : 146
# BMI: 45.50572340026272
# 결과: 과체중
#
# 이름 : 나카
# 몸무게: 92
# 키 : 141
# BMI: 46.27533826266285
# 결과: 과체중
#
# 이름 : 바차
# 몸무게: 40
# 키 : 173
# BMI: 13.364963747535834
# 결과: 저체중
#
# 이름 : 사차
# 몸무게: 98
# 키 : 178
# BMI: 30.930438076000502
# 결과: 과체중
#
# 이름 : 바하
# 몸무게: 41
# 키 : 180
# BMI: 12.65432098765432
# 결과: 저체중
#
# 이름 : 아자
# 몸무게: 71
# 키 : 152
# BMI: 30.730609418282548
# 결과: 과체중
#
# 이름 : 바라
# 몸무게: 47
# 키 : 162
# BMI: 17.908855357415025
# 결과: 저체중
#
# 이름 : 카바
# 몸무게: 75
# 키 : 157
# BMI: 30.427197857925268
# 결과: 과체중
#
# 이름 : 바카
# 몸무게: 95
# 키 : 199
# BMI: 23.989293199666673
# 결과: 정상체중
#
# 이름 : 나타
# 몸무게: 73
# 키 : 199
# BMI: 18.433877932375445
# 결과: 저체중
#
# 이름 : 카바
# 몸무게: 51
# 키 : 183
# BMI: 15.228881125145568
# 결과: 저체중
#
# 이름 : 차아
# 몸무게: 65
# 키 : 140
# BMI: 33.163265306122454
# 결과: 과체중
#
# 이름 : 자아
# 몸무게: 69
# 키 : 176
# BMI: 22.275309917355372
# 결과: 정상체중
#
# 이름 : 다바
# 몸무게: 57
# 키 : 195
# BMI: 14.990138067061144
# 결과: 저체중
#
# 이름 : 아차
# 몸무게: 82
# 키 : 173
# BMI: 27.39817568244846
# 결과: 과체중
#
# 이름 : 바타
# 몸무게: 59
# 키 : 187
# BMI: 16.872086705367607
# 결과: 저체중
#
# 이름 : 카바
# 몸무게: 75
# 키 : 154
# BMI: 31.624219935908247
# 결과: 과체중
#
# 이름 : 다가
# 몸무게: 59
# 키 : 141
# BMI: 29.676575624968567
# 결과: 과체중
#
# 이름 : 가가
# 몸무게: 49
# 키 : 175
# BMI: 16.0
# 결과: 저체중
#
# 이름 : 차사
# 몸무게: 67
# 키 : 163
# BMI: 25.21735857578381
# 결과: 과체중
#
# 이름 : 나다
# 몸무게: 43
# 키 : 184
# BMI: 12.700850661625708
# 결과: 저체중
#
# 이름 : 바바
# 몸무게: 96
# 키 : 176
# BMI: 30.991735537190085
# 결과: 과체중
#
# 이름 : 바마
# 몸무게: 86
# 키 : 196
# BMI: 22.38650562265723
# 결과: 정상체중
#
# 이름 : 하바
# 몸무게: 51
# 키 : 141
# BMI: 25.65263316734571
# 결과: 과체중
#
# 이름 : 가타
# 몸무게: 88
# 키 : 146
# BMI: 41.28354287858886
# 결과: 과체중
#
# 이름 : 하라
# 몸무게: 40
# 키 : 154
# BMI: 16.866250632484398
# 결과: 저체중
#
# 이름 : 아바
# 몸무게: 94
# 키 : 184
# BMI: 27.764650283553873
# 결과: 과체중
#
# 이름 : 카바
# 몸무게: 52
# 키 : 185
# BMI: 15.193571950328705
# 결과: 저체중
#
# 이름 : 차나
# 몸무게: 55
# 키 : 185
# BMI: 16.070124178232284
# 결과: 저체중
#
# 이름 : 아하
# 몸무게: 81
# 키 : 158
# BMI: 32.446723281525394
# 결과: 과체중
#
# 이름 : 라바
# 몸무게: 80
# 키 : 166
# BMI: 29.03178980984178
# 결과: 과체중
#
# 이름 : 타바
# 몸무게: 52
# 키 : 197
# BMI: 13.398953850910871
# 결과: 저체중
#
# 이름 : 마아
# 몸무게: 46
# 키 : 187
# BMI: 13.154508278761186
# 결과: 저체중
#
# 이름 : 하하
# 몸무게: 66
# 키 : 158
# BMI: 26.43807082198365
# 결과: 과체중
#
# 이름 : 파파
# 몸무게: 80
# 키 : 193
# BMI: 21.47708663319821
# 결과: 정상체중
#
# 이름 : 하자
# 몸무게: 96
# 키 : 167
# BMI: 34.42217361683818
# 결과: 과체중
#
# 이름 : 차하
# 몸무게: 71
# 키 : 141
# BMI: 35.71248931140285
# 결과: 과체중
#
# 이름 : 가바
# 몸무게: 83
# 키 : 143
# BMI: 40.58878184752311
# 결과: 과체중
#
# 이름 : 사바
# 몸무게: 79
# 키 : 169
# BMI: 27.660095935016283
# 결과: 과체중
#
# 이름 : 아나
# 몸무게: 83
# 키 : 153
# BMI: 35.45644837455679
# 결과: 과체중
#
# 이름 : 자다
# 몸무게: 72
# 키 : 159
# BMI: 28.479886080455675
# 결과: 과체중
#
# 이름 : 타파
# 몸무게: 49
# 키 : 186
# BMI: 14.163487108336222
# 결과: 저체중
#
# 이름 : 사나
# 몸무게: 48
# 키 : 170
# BMI: 16.60899653979239
# 결과: 저체중
#
# 이름 : 아자
# 몸무게: 98
# 키 : 199
# BMI: 24.74684982702457
# 결과: 정상체중
#
# 이름 : 마바
# 몸무게: 93
# 키 : 195
# BMI: 24.45759368836292
# 결과: 정상체중
#
# 이름 : 마아
# 몸무게: 44
# 키 : 191
# BMI: 12.06107288725638
# 결과: 저체중
#
# 이름 : 자나
# 몸무게: 50
# 키 : 192
# BMI: 13.563368055555555
# 결과: 저체중
#
# 이름 : 카파
# 몸무게: 78
# 키 : 187
# BMI: 22.305470559638533
# 결과: 정상체중
#
# 이름 : 파사
# 몸무게: 56
# 키 : 184
# BMI: 16.5406427221172
# 결과: 저체중
#
# 이름 : 차다
# 몸무게: 49
# 키 : 196
# BMI: 12.755102040816327
# 결과: 저체중
#
# 이름 : 자차
# 몸무게: 68
# 키 : 177
# BMI: 21.705129432793896
# 결과: 정상체중
#
# 이름 : 아타
# 몸무게: 61
# 키 : 185
# BMI: 17.82322863403944
# 결과: 저체중
#
# 이름 : 마나
# 몸무게: 41
# 키 : 170
# BMI: 14.186851211072666
# 결과: 저체중
#
# 이름 : 나타
# 몸무게: 42
# 키 : 166
# BMI: 15.241689650166935
# 결과: 저체중
#
# 이름 : 카나
# 몸무게: 78
# 키 : 188
# BMI: 22.068809416025353
# 결과: 정상체중
#
# 이름 : 사아
# 몸무게: 81
# 키 : 147
# BMI: 37.48438150770512
# 결과: 과체중
#
# 이름 : 카자
# 몸무게: 48
# 키 : 166
# BMI: 17.419073885905068
# 결과: 저체중
#
# 이름 : 아아
# 몸무게: 73
# 키 : 180
# BMI: 22.530864197530864
# 결과: 정상체중
#
# 이름 : 타자
# 몸무게: 77
# 키 : 190
# BMI: 21.329639889196677
# 결과: 정상체중
#
# 이름 : 다나
# 몸무게: 40
# 키 : 177
# BMI: 12.767723195761114
# 결과: 저체중
#
# 이름 : 다타
# 몸무게: 91
# 키 : 165
# BMI: 33.425160697887975
# 결과: 과체중
#
# 이름 : 가가
# 몸무게: 83
# 키 : 172
# BMI: 28.055705786911847
# 결과: 과체중
#
# 이름 : 나아
# 몸무게: 97
# 키 : 148
# BMI: 44.284149013878746
# 결과: 과체중
#
# 이름 : 다차
# 몸무게: 59
# 키 : 172
# BMI: 19.94321254732288
# 결과: 정상체중
#
# 이름 : 바마
# 몸무게: 69
# 키 : 192
# BMI: 18.717447916666668
# 결과: 정상체중
#
# 이름 : 차카
# 몸무게: 60
# 키 : 166
# BMI: 21.773842357381334
# 결과: 정상체중
#
# 이름 : 나라
# 몸무게: 62
# 키 : 179
# BMI: 19.350207546580943
# 결과: 정상체중
#
# 이름 : 바마
# 몸무게: 63
# 키 : 197
# BMI: 16.2333479347574
# 결과: 저체중
#
# 이름 : 가아
# 몸무게: 57
# 키 : 196
# BMI: 14.83756768013328
# 결과: 저체중
#
# 이름 : 하다
# 몸무게: 89
# 키 : 197
# BMI: 22.932824860212836
# 결과: 정상체중
#
# 이름 : 아나
# 몸무게: 68
# 키 : 197
# BMI: 17.52170888196037
# 결과: 저체중
#
# 이름 : 바다
# 몸무게: 81
# 키 : 188
# BMI: 22.917609778180175
# 결과: 정상체중
#
# 이름 : 나나
# 몸무게: 54
# 키 : 197
# BMI: 13.914298229792058
# 결과: 저체중
#
# 이름 : 아마
# 몸무게: 71
# 키 : 173
# BMI: 23.722810651876106
# 결과: 정상체중
#
# 이름 : 바가
# 몸무게: 57
# 키 : 173
# BMI: 19.045073340238563
# 결과: 정상체중
#
# 이름 : 자다
# 몸무게: 41
# 키 : 180
# BMI: 12.65432098765432
# 결과: 저체중
#
# 이름 : 사사
# 몸무게: 54
# 키 : 161
# BMI: 20.832529609197174
# 결과: 정상체중
#
# 이름 : 나타
# 몸무게: 98
# 키 : 192
# BMI: 26.58420138888889
# 결과: 과체중
#
# 이름 : 가마
# 몸무게: 86
# 키 : 183
# BMI: 25.680074054167036
# 결과: 과체중
#
# 이름 : 아가
# 몸무게: 51
# 키 : 185
# BMI: 14.901387874360847
# 결과: 저체중
#
# 이름 : 바라
# 몸무게: 48
# 키 : 145
# BMI: 22.829964328180736
# 결과: 정상체중
#
# 이름 : 자아
# 몸무게: 82
# 키 : 180
# BMI: 25.30864197530864
# 결과: 과체중
#
# 이름 : 사타
# 몸무게: 86
# 키 : 174
# BMI: 28.405337561104506
# 결과: 과체중
#
# 이름 : 자차
# 몸무게: 73
# 키 : 179
# BMI: 22.783308885490467
# 결과: 정상체중
#
# 이름 : 카가
# 몸무게: 95
# 키 : 165
# BMI: 34.894398530762174
# 결과: 과체중
#
# 이름 : 하하
# 몸무게: 48
# 키 : 189
# BMI: 13.437473754934073
# 결과: 저체중
#
# 이름 : 자아
# 몸무게: 78
# 키 : 142
# BMI: 38.68280103154136
# 결과: 과체중
#
# 이름 : 사바
# 몸무게: 78
# 키 : 150
# BMI: 34.666666666666664
# 결과: 과체중
#
# 이름 : 다라
# 몸무게: 59
# 키 : 178
# BMI: 18.621386188612547
# 결과: 정상체중
#
# 이름 : 다카
# 몸무게: 47
# 키 : 152
# BMI: 20.342797783933516
# 결과: 정상체중
#
# 이름 : 자마
# 몸무게: 67
# 키 : 184
# BMI: 19.78969754253308
# 결과: 정상체중
#
# 이름 : 가나
# 몸무게: 88
# 키 : 193
# BMI: 23.624795296518027
# 결과: 정상체중
#
# 이름 : 가차
# 몸무게: 90
# 키 : 186
# BMI: 26.014568158168572
# 결과: 과체중
#
# 이름 : 타자
# 몸무게: 97
# 키 : 149
# BMI: 43.69172559794604
# 결과: 과체중
#
# 이름 : 사차
# 몸무게: 77
# 키 : 192
# BMI: 20.887586805555557
# 결과: 정상체중
#
# 이름 : 아마
# 몸무게: 45
# 키 : 149
# BMI: 20.269357236160534
# 결과: 정상체중
#
# 이름 : 다라
# 몸무게: 75
# 키 : 152
# BMI: 32.46191135734072
# 결과: 과체중
#
# 이름 : 카카
# 몸무게: 67
# 키 : 181
# BMI: 20.45114617990904
# 결과: 정상체중
#
# 이름 : 타바
# 몸무게: 94
# 키 : 186
# BMI: 27.170771187420506
# 결과: 과체중
#
# 이름 : 하바
# 몸무게: 69
# 키 : 172
# BMI: 23.323418063818284
# 결과: 정상체중
#
# 이름 : 하마
# 몸무게: 76
# 키 : 147
# BMI: 35.17053079735296
# 결과: 과체중
#
# 이름 : 파라
# 몸무게: 65
# 키 : 197
# BMI: 16.74869231363859
# 결과: 저체중
#
# 이름 : 파카
# 몸무게: 86
# 키 : 174
# BMI: 28.405337561104506
# 결과: 과체중
#
# 이름 : 사카
# 몸무게: 40
# 키 : 199
# BMI: 10.100755031438599
# 결과: 저체중
#
# 이름 : 카가
# 몸무게: 89
# 키 : 185
# BMI: 26.004382761139514
# 결과: 과체중
#
# 이름 : 가나
# 몸무게: 99
# 키 : 172
# BMI: 33.46403461330449
# 결과: 과체중
#
# 이름 : 카하
# 몸무게: 76
# 키 : 166
# BMI: 27.58020031934969
# 결과: 과체중
#
# 이름 : 자바
# 몸무게: 67
# 키 : 186
# BMI: 19.366400739969936
# 결과: 정상체중
#
# 이름 : 파바
# 몸무게: 84
# 키 : 159
# BMI: 33.22653376053162
# 결과: 과체중
#
# 이름 : 카자
# 몸무게: 95
# 키 : 148
# BMI: 43.371073776479186
# 결과: 과체중
#
# 이름 : 카카
# 몸무게: 52
# 키 : 192
# BMI: 14.105902777777779
# 결과: 저체중
#
# 이름 : 카파
# 몸무게: 74
# 키 : 176
# BMI: 23.889462809917354
# 결과: 정상체중
#
# 이름 : 카자
# 몸무게: 78
# 키 : 166
# BMI: 28.305995064595734
# 결과: 과체중
#
# 이름 : 가자
# 몸무게: 70
# 키 : 152
# BMI: 30.297783933518005
# 결과: 과체중
#
# 이름 : 아다
# 몸무게: 98
# 키 : 148
# BMI: 44.74068663257852
# 결과: 과체중
#
# 이름 : 나아
# 몸무게: 41
# 키 : 182
# BMI: 12.377732157951938
# 결과: 저체중
#
# 이름 : 차하
# 몸무게: 40
# 키 : 167
# BMI: 14.342572340349243
# 결과: 저체중
#
# 이름 : 다가
# 몸무게: 67
# 키 : 151
# BMI: 29.384676110696898
# 결과: 과체중
#
# 이름 : 타가
# 몸무게: 56
# 키 : 160
# BMI: 21.874999999999996
# 결과: 정상체중
#
# 이름 : 가하
# 몸무게: 94
# 키 : 192
# BMI: 25.499131944444446
# 결과: 과체중
#
# 이름 : 파하
# 몸무게: 91
# 키 : 193
# BMI: 24.43018604526296
# 결과: 정상체중
#
# 이름 : 카나
# 몸무게: 64
# 키 : 147
# BMI: 29.617289092507754
# 결과: 과체중
#
# 이름 : 마가
# 몸무게: 55
# 키 : 167
# BMI: 19.721036967980208
# 결과: 정상체중
#
# 이름 : 카파
# 몸무게: 96
# 키 : 175
# BMI: 31.346938775510203
# 결과: 과체중
#
# 이름 : 가자
# 몸무게: 58
# 키 : 147
# BMI: 26.84066824008515
# 결과: 과체중
#
# 이름 : 사자
# 몸무게: 79
# 키 : 150
# BMI: 35.111111111111114
# 결과: 과체중
#
# 이름 : 자자
# 몸무게: 86
# 키 : 194
# BMI: 22.85046232330747
# 결과: 정상체중
#
# 이름 : 타파
# 몸무게: 89
# 키 : 189
# BMI: 24.915315920606925
# 결과: 정상체중
#
# 이름 : 다다
# 몸무게: 93
# 키 : 173
# BMI: 31.073540713020815
# 결과: 과체중
#
# 이름 : 라나
# 몸무게: 62
# 키 : 154
# BMI: 26.14268848035082
# 결과: 과체중
#
# 이름 : 다라
# 몸무게: 72
# 키 : 157
# BMI: 29.21010994360826
# 결과: 과체중
#
# 이름 : 파카
# 몸무게: 53
# 키 : 160
# BMI: 20.703124999999996
# 결과: 정상체중
#
# 이름 : 자차
# 몸무게: 66
# 키 : 180
# BMI: 20.37037037037037
# 결과: 정상체중
#
# 이름 : 카사
# 몸무게: 63
# 키 : 193
# BMI: 16.91320572364359
# 결과: 저체중
#
# 이름 : 자자
# 몸무게: 46
# 키 : 163
# BMI: 17.31341036546351
# 결과: 저체중
#
# 이름 : 파파
# 몸무게: 84
# 키 : 150
# BMI: 37.333333333333336
# 결과: 과체중
#
# 이름 : 차다
# 몸무게: 95
# 키 : 190
# BMI: 26.315789473684212
# 결과: 과체중
#
# 이름 : 바바
# 몸무게: 77
# 키 : 181
# BMI: 23.503556057507403
# 결과: 정상체중
#
# 이름 : 카라
# 몸무게: 71
# 키 : 140
# BMI: 36.22448979591837
# 결과: 과체중
#
# 이름 : 다바
# 몸무게: 41
# 키 : 187
# BMI: 11.724670422374102
# 결과: 저체중
#
# 이름 : 카가
# 몸무게: 43
# 키 : 195
# BMI: 11.308349769888233
# 결과: 저체중
#
# 이름 : 파사
# 몸무게: 53
# 키 : 186
# BMI: 15.31969013758816
# 결과: 저체중
#
# 이름 : 자아
# 몸무게: 43
# 키 : 171
# BMI: 14.705379432987929
# 결과: 저체중
#
# 이름 : 차타
# 몸무게: 96
# 키 : 192
# BMI: 26.041666666666668
# 결과: 과체중
#
# 이름 : 사하
# 몸무게: 84
# 키 : 144
# BMI: 40.50925925925926
# 결과: 과체중
#
# 이름 : 라아
# 몸무게: 80
# 키 : 192
# BMI: 21.70138888888889
# 결과: 정상체중
#
# 이름 : 차카
# 몸무게: 58
# 키 : 175
# BMI: 18.93877551020408
# 결과: 정상체중
#
# 이름 : 나타
# 몸무게: 52
# 키 : 161
# BMI: 20.060954438486167
# 결과: 정상체중
#
# 이름 : 다하
# 몸무게: 54
# 키 : 176
# BMI: 17.43285123966942
# 결과: 저체중
#
# 이름 : 마가
# 몸무게: 43
# 키 : 151
# BMI: 18.85882198149204
# 결과: 정상체중
#
# 이름 : 아타
# 몸무게: 63
# 키 : 142
# BMI: 31.243800833168024
# 결과: 과체중
#
# 이름 : 사바
# 몸무게: 46
# 키 : 191
# BMI: 12.609303473040761
# 결과: 저체중
#
# 이름 : 타아
# 몸무게: 45
# 키 : 153
# BMI: 19.223375624759708
# 결과: 정상체중
#
# 이름 : 하아
# 몸무게: 95
# 키 : 190
# BMI: 26.315789473684212
# 결과: 과체중
#
# 이름 : 바자
# 몸무게: 40
# 키 : 185
# BMI: 11.68736303871439
# 결과: 저체중
#
# 이름 : 차사
# 몸무게: 47
# 키 : 154
# BMI: 19.81784449316917
# 결과: 정상체중
#
# 이름 : 파마
# 몸무게: 75
# 키 : 199
# BMI: 18.938915683947375
# 결과: 정상체중
#
# 이름 : 하자
# 몸무게: 48
# 키 : 172
# BMI: 16.224986479177936
# 결과: 저체중
#
# 이름 : 파차
# 몸무게: 51
# 키 : 151
# BMI: 22.367440024560327
# 결과: 정상체중
#
# 이름 : 타자
# 몸무게: 59
# 키 : 145
# BMI: 28.061831153388823
# 결과: 과체중
#
# 이름 : 차마
# 몸무게: 78
# 키 : 197
# BMI: 20.098430776366307
# 결과: 정상체중
#
# 이름 : 하아
# 몸무게: 66
# 키 : 146
# BMI: 30.962657158941646
# 결과: 과체중
#
# 이름 : 차사
# 몸무게: 66
# 키 : 181
# BMI: 20.1459051921492
# 결과: 정상체중
#
# 이름 : 바사
# 몸무게: 79
# 키 : 187
# BMI: 22.59143813091595
# 결과: 정상체중
#
# 이름 : 카타
# 몸무게: 95
# 키 : 142
# BMI: 47.113667923031144
# 결과: 과체중
#
# 이름 : 가다
# 몸무게: 68
# 키 : 154
# BMI: 28.67262607522348
# 결과: 과체중
#
# 이름 : 바사
# 몸무게: 89
# 키 : 177
# BMI: 28.40818411056848
# 결과: 과체중
#
# 이름 : 아마
# 몸무게: 41
# 키 : 194
# BMI: 10.893825061111702
# 결과: 저체중
#
# 이름 : 나다
# 몸무게: 47
# 키 : 171
# BMI: 16.073321705824014
# 결과: 저체중
#
# 이름 : 다나
# 몸무게: 77
# 키 : 161
# BMI: 29.705644072373747
# 결과: 과체중
#
# 이름 : 라타
# 몸무게: 53
# 키 : 168
# BMI: 18.77834467120182
# 결과: 정상체중
#
# 이름 : 자마
# 몸무게: 44
# 키 : 164
# BMI: 16.359309934562763
# 결과: 저체중
#
# 이름 : 바차
# 몸무게: 67
# 키 : 147
# BMI: 31.005599518719055
# 결과: 과체중
#
# 이름 : 바자
# 몸무게: 80
# 키 : 151
# BMI: 35.086180430682866
# 결과: 과체중
#
# 이름 : 나바
# 몸무게: 84
# 키 : 189
# BMI: 23.515579071134628
# 결과: 정상체중
#
# 이름 : 가나
# 몸무게: 61
# 키 : 190
# BMI: 16.897506925207757
# 결과: 저체중
#
# 이름 : 나하
# 몸무게: 66
# 키 : 184
# BMI: 19.494328922495274
# 결과: 정상체중
#
# 이름 : 타타
# 몸무게: 49
# 키 : 157
# BMI: 19.879102600511175
# 결과: 정상체중
#
# 이름 : 가하
# 몸무게: 53
# 키 : 161
# BMI: 20.446742023841672
# 결과: 정상체중
#
# 이름 : 파아
# 몸무게: 68
# 키 : 140
# BMI: 34.693877551020414
# 결과: 과체중
#
# 이름 : 가라
# 몸무게: 81
# 키 : 168
# BMI: 28.69897959183674
# 결과: 과체중
#
# 이름 : 사하
# 몸무게: 93
# 키 : 174
# BMI: 30.71739992072929
# 결과: 과체중
#
# 이름 : 아차
# 몸무게: 73
# 키 : 171
# BMI: 24.96494647925858
# 결과: 정상체중
#
# 이름 : 나나
# 몸무게: 51
# 키 : 198
# BMI: 13.008876645240282
# 결과: 저체중
#
# 이름 : 나하
# 몸무게: 72
# 키 : 157
# BMI: 29.21010994360826
# 결과: 과체중
#
# 이름 : 카타
# 몸무게: 61
# 키 : 187
# BMI: 17.444021847922443
# 결과: 저체중
#
# 이름 : 라파
# 몸무게: 50
# 키 : 157
# BMI: 20.28479857195018
# 결과: 정상체중
#
# 이름 : 아마
# 몸무게: 76
# 키 : 152
# BMI: 32.89473684210526
# 결과: 과체중
#
# 이름 : 차나
# 몸무게: 55
# 키 : 160
# BMI: 21.484374999999996
# 결과: 정상체중
#
# 이름 : 타자
# 몸무게: 79
# 키 : 140
# BMI: 40.3061224489796
# 결과: 과체중
#
# 이름 : 카마
# 몸무게: 54
# 키 : 195
# BMI: 14.201183431952664
# 결과: 저체중
#
# 이름 : 하다
# 몸무게: 63
# 키 : 144
# BMI: 30.381944444444446
# 결과: 과체중
#
# 이름 : 파라
# 몸무게: 97
# 키 : 171
# BMI: 33.1726001162751
# 결과: 과체중
#
# 이름 : 마사
# 몸무게: 53
# 키 : 146
# BMI: 24.86395196096829
# 결과: 정상체중
#
# 이름 : 타바
# 몸무게: 55
# 키 : 180
# BMI: 16.975308641975307
# 결과: 저체중
#
# 이름 : 사라
# 몸무게: 73
# 키 : 193
# BMI: 19.597841552793366
# 결과: 정상체중
#
# 이름 : 차바
# 몸무게: 62
# 키 : 185
# BMI: 18.115412710007302
# 결과: 저체중
#
# 이름 : 바다
# 몸무게: 99
# 키 : 172
# BMI: 33.46403461330449
# 결과: 과체중
#
# 이름 : 자바
# 몸무게: 44
# 키 : 151
# BMI: 19.297399236875574
# 결과: 정상체중
#
# 이름 : 아나
# 몸무게: 85
# 키 : 171
# BMI: 29.06877329776684
# 결과: 과체중
#
# 이름 : 아사
# 몸무게: 73
# 키 : 193
# BMI: 19.597841552793366
# 결과: 정상체중
#
# 이름 : 카라
# 몸무게: 94
# 키 : 146
# BMI: 44.0983298930381
# 결과: 과체중
#
# 이름 : 바사
# 몸무게: 76
# 키 : 196
# BMI: 19.78342357351104
# 결과: 정상체중
#
# 이름 : 다바
# 몸무게: 60
# 키 : 194
# BMI: 15.942183016261028
# 결과: 저체중
#
# 이름 : 바하
# 몸무게: 99
# 키 : 142
# BMI: 49.097401309264036
# 결과: 과체중
#
# 이름 : 카카
# 몸무게: 69
# 키 : 147
# BMI: 31.93113980285992
# 결과: 과체중
#
# 이름 : 카하
# 몸무게: 62
# 키 : 143
# BMI: 30.319331018631722
# 결과: 과체중
#
# 이름 : 가마
# 몸무게: 97
# 키 : 144
# BMI: 46.77854938271605
# 결과: 과체중
#
# 이름 : 타마
# 몸무게: 59
# 키 : 188
# BMI: 16.693073789044817
# 결과: 저체중
#
# 이름 : 카아
# 몸무게: 94
# 키 : 152
# BMI: 40.68559556786703
# 결과: 과체중
#
# 이름 : 카라
# 몸무게: 90
# 키 : 197
# BMI: 23.19049704965343
# 결과: 정상체중
#
# 이름 : 하타
# 몸무게: 66
# 키 : 146
# BMI: 30.962657158941646
# 결과: 과체중
#
# 이름 : 라바
# 몸무게: 47
# 키 : 178
# BMI: 14.833985607877793
# 결과: 저체중
#
# 이름 : 차마
# 몸무게: 45
# 키 : 172
# BMI: 15.210924824229314
# 결과: 저체중
#
# 이름 : 타마
# 몸무게: 74
# 키 : 146
# BMI: 34.71570651154063
# 결과: 과체중
#
# 이름 : 라바
# 몸무게: 99
# 키 : 178
# BMI: 31.246054791061734
# 결과: 과체중
#
# 이름 : 파가
# 몸무게: 50
# 키 : 161
# BMI: 19.28937926777516
# 결과: 정상체중
#
# 이름 : 가다
# 몸무게: 81
# 키 : 181
# BMI: 24.724520008546747
# 결과: 정상체중
#
# 이름 : 가다
# 몸무게: 64
# 키 : 163
# BMI: 24.088223117166624
# 결과: 정상체중
#
# 이름 : 타파
# 몸무게: 46
# 키 : 167
# BMI: 16.493958191401628
# 결과: 저체중
#
# 이름 : 마마
# 몸무게: 72
# 키 : 171
# BMI: 24.622960911049557
# 결과: 정상체중
#
# 이름 : 하차
# 몸무게: 91
# 키 : 158
# BMI: 36.45249158788655
# 결과: 과체중
#
# 이름 : 차나
# 몸무게: 56
# 키 : 146
# BMI: 26.27134546819291
# 결과: 과체중
#
# 이름 : 가아
# 몸무게: 92
# 키 : 159
# BMI: 36.39096554724892
# 결과: 과체중
#
# 이름 : 자차
# 몸무게: 62
# 키 : 159
# BMI: 24.524346347059055
# 결과: 정상체중
#
# 이름 : 카타
# 몸무게: 67
# 키 : 160
# BMI: 26.171874999999996
# 결과: 과체중
#
# 이름 : 다바
# 몸무게: 48
# 키 : 186
# BMI: 13.874436351023238
# 결과: 저체중
#
# 이름 : 사차
# 몸무게: 95
# 키 : 166
# BMI: 34.47525039918711
# 결과: 과체중
#
# 이름 : 카타
# 몸무게: 40
# 키 : 157
# BMI: 16.227838857560144
# 결과: 저체중
#
# 이름 : 아가
# 몸무게: 74
# 키 : 143
# BMI: 36.18758863514109
# 결과: 과체중
#
# 이름 : 나마
# 몸무게: 85
# 키 : 158
# BMI: 34.049030604069856
# 결과: 과체중
#
# 이름 : 타라
# 몸무게: 91
# 키 : 171
# BMI: 31.120686707020965
# 결과: 과체중
#
# 이름 : 아바
# 몸무게: 63
# 키 : 168
# BMI: 22.321428571428577
# 결과: 정상체중
#
# 이름 : 자하
# 몸무게: 66
# 키 : 190
# BMI: 18.282548476454295
# 결과: 저체중
#
# 이름 : 라카
# 몸무게: 78
# 키 : 173
# BMI: 26.061679307694877
# 결과: 과체중
#
# 이름 : 하아
# 몸무게: 88
# 키 : 148
# BMI: 40.17531044558072
# 결과: 과체중
#
# 이름 : 아타
# 몸무게: 45
# 키 : 180
# BMI: 13.888888888888888
# 결과: 저체중
#
# 이름 : 마타
# 몸무게: 70
# 키 : 146
# BMI: 32.839181835241135
# 결과: 과체중
#
# 이름 : 타라
# 몸무게: 58
# 키 : 148
# BMI: 26.47918188458729
# 결과: 과체중
#
# 이름 : 하가
# 몸무게: 42
# 키 : 151
# BMI: 18.420244726108503
# 결과: 저체중
#
# 이름 : 사다
# 몸무게: 82
# 키 : 175
# BMI: 26.775510204081634
# 결과: 과체중
#
# 이름 : 하파
# 몸무게: 60
# 키 : 194
# BMI: 15.942183016261028
# 결과: 저체중
#
# 이름 : 라카
# 몸무게: 72
# 키 : 150
# BMI: 32.0
# 결과: 과체중
#
# 이름 : 라나
# 몸무게: 89
# 키 : 184
# BMI: 26.287807183364837
# 결과: 과체중
#
# 이름 : 가타
# 몸무게: 54
# 키 : 150
# BMI: 24.0
# 결과: 정상체중
#
# 이름 : 차타
# 몸무게: 77
# 키 : 192
# BMI: 20.887586805555557
# 결과: 정상체중
#
# 이름 : 가가
# 몸무게: 47
# 키 : 157
# BMI: 19.067710657633167
# 결과: 정상체중
#
# 이름 : 타라
# 몸무게: 81
# 키 : 191
# BMI: 22.20333872426743
# 결과: 정상체중
#
# 이름 : 마파
# 몸무게: 89
# 키 : 164
# BMI: 33.09042236763832
# 결과: 과체중
#
# 이름 : 나카
# 몸무게: 71
# 키 : 179
# BMI: 22.15910864205237
# 결과: 정상체중
#
# 이름 : 자라
# 몸무게: 96
# 키 : 175
# BMI: 31.346938775510203
# 결과: 과체중
#
# 이름 : 사가
# 몸무게: 90
# 키 : 173
# BMI: 30.071168431955627
# 결과: 과체중
#
# 이름 : 나차
# 몸무게: 49
# 키 : 161
# BMI: 18.90359168241966
# 결과: 정상체중
#
# 이름 : 다타
# 몸무게: 76
# 키 : 147
# BMI: 35.17053079735296
# 결과: 과체중
#
# 이름 : 가자
# 몸무게: 73
# 키 : 174
# BMI: 24.111507464658473
# 결과: 정상체중
#
# 이름 : 타하
# 몸무게: 48
# 키 : 187
# BMI: 13.72644342131602
# 결과: 저체중
#
# 이름 : 아카
# 몸무게: 41
# 키 : 197
# BMI: 10.56455976706434
# 결과: 저체중
#
# 이름 : 아하
# 몸무게: 97
# 키 : 143
# BMI: 47.43508240011737
# 결과: 과체중
#
# 이름 : 아타
# 몸무게: 49
# 키 : 196
# BMI: 12.755102040816327
# 결과: 저체중
#
# 이름 : 바자
# 몸무게: 66
# 키 : 194
# BMI: 17.53640131788713
# 결과: 저체중
#
# 이름 : 파가
# 몸무게: 67
# 키 : 189
# BMI: 18.75647378292881
# 결과: 정상체중
#
# 이름 : 하다
# 몸무게: 85
# 키 : 173
# BMI: 28.40054796351365
# 결과: 과체중
#
# 이름 : 아사
# 몸무게: 64
# 키 : 159
# BMI: 25.315454293738377
# 결과: 과체중
#
# 이름 : 파마
# 몸무게: 81
# 키 : 154
# BMI: 34.15415753078091
# 결과: 과체중
#
# 이름 : 파차
# 몸무게: 98
# 키 : 191
# BMI: 26.863298703434666
# 결과: 과체중
#
# 이름 : 가타
# 몸무게: 87
# 키 : 184
# BMI: 25.697069943289225
# 결과: 과체중
#
# 이름 : 카라
# 몸무게: 80
# 키 : 161
# BMI: 30.86300682844026
# 결과: 과체중
#
# 이름 : 마아
# 몸무게: 43
# 키 : 193
# BMI: 11.543934065344036
# 결과: 저체중
#
# 이름 : 바다
# 몸무게: 54
# 키 : 174
# BMI: 17.8359096313912
# 결과: 저체중
#
# 이름 : 카가
# 몸무게: 86
# 키 : 165
# BMI: 31.58861340679523
# 결과: 과체중
#
# 이름 : 라자
# 몸무게: 75
# 키 : 146
# BMI: 35.1848376806155
# 결과: 과체중
#
# 이름 : 타라
# 몸무게: 49
# 키 : 150
# BMI: 21.77777777777778
# 결과: 정상체중
#
# 이름 : 다아
# 몸무게: 74
# 키 : 164
# BMI: 27.513384889946465
# 결과: 과체중
#
# 이름 : 마사
# 몸무게: 82
# 키 : 189
# BMI: 22.955684331345708
# 결과: 정상체중
#
# 이름 : 사카
# 몸무게: 77
# 키 : 162
# BMI: 29.340039628105465
# 결과: 과체중
#
# 이름 : 마자
# 몸무게: 73
# 키 : 141
# BMI: 36.718474925808565
# 결과: 과체중
#
# 이름 : 하카
# 몸무게: 61
# 키 : 153
# BMI: 26.05835362467427
# 결과: 과체중
#
# 이름 : 나마
# 몸무게: 76
# 키 : 181
# BMI: 23.198315069747565
# 결과: 정상체중
#
# 이름 : 가아
# 몸무게: 50
# 키 : 162
# BMI: 19.05197378448407
# 결과: 정상체중
#
# 이름 : 사마
# 몸무게: 66
# 키 : 176
# BMI: 21.306818181818183
# 결과: 정상체중
#
# 이름 : 차차
# 몸무게: 95
# 키 : 195
# BMI: 24.983563445101908
# 결과: 정상체중
#
# 이름 : 라라
# 몸무게: 82
# 키 : 171
# BMI: 28.042816593139772
# 결과: 과체중
#
# 이름 : 나파
# 몸무게: 89
# 키 : 164
# BMI: 33.09042236763832
# 결과: 과체중
#
# 이름 : 아파
# 몸무게: 54
# 키 : 192
# BMI: 14.6484375
# 결과: 저체중
#
# 이름 : 나사
# 몸무게: 57
# 키 : 156
# BMI: 23.422090729783037
# 결과: 정상체중
#
# 이름 : 하파
# 몸무게: 98
# 키 : 197
# BMI: 25.25187456517818
# 결과: 과체중
#
# 이름 : 아파
# 몸무게: 82
# 키 : 159
# BMI: 32.4354258138523
# 결과: 과체중
#
# 이름 : 아라
# 몸무게: 61
# 키 : 146
# BMI: 28.61700131356728
# 결과: 과체중
#
# 이름 : 바차
# 몸무게: 90
# 키 : 186
# BMI: 26.014568158168572
# 결과: 과체중
#
# 이름 : 마카
# 몸무게: 74
# 키 : 191
# BMI: 20.284531674022094
# 결과: 정상체중
#
# 이름 : 자다
# 몸무게: 96
# 키 : 152
# BMI: 41.551246537396125
# 결과: 과체중
#
# 이름 : 자가
# 몸무게: 40
# 키 : 174
# BMI: 13.21178491214163
# 결과: 저체중
#
# 이름 : 마타
# 몸무게: 72
# 키 : 168
# BMI: 25.510204081632658
# 결과: 과체중
#
# 이름 : 차라
# 몸무게: 81
# 키 : 148
# BMI: 36.979547114682255
# 결과: 과체중
#
# 이름 : 타나
# 몸무게: 46
# 키 : 174
# BMI: 15.193552648962875
# 결과: 저체중
#
# 이름 : 자아
# 몸무게: 72
# 키 : 191
# BMI: 19.736301088237713
# 결과: 정상체중
#
# 이름 : 라자
# 몸무게: 86
# 키 : 167
# BMI: 30.83653053175087
# 결과: 과체중
#
# 이름 : 카자
# 몸무게: 82
# 키 : 172
# BMI: 27.717685235262305
# 결과: 과체중
#
# 이름 : 하바
# 몸무게: 95
# 키 : 158
# BMI: 38.05479891043102
# 결과: 과체중
#
# 이름 : 다자
# 몸무게: 72
# 키 : 184
# BMI: 21.266540642722116
# 결과: 정상체중
#
# 이름 : 파자
# 몸무게: 93
# 키 : 145
# BMI: 44.23305588585018
# 결과: 과체중
#
# 이름 : 아나
# 몸무게: 64
# 키 : 176
# BMI: 20.66115702479339
# 결과: 정상체중
#
# 이름 : 다타
# 몸무게: 80
# 키 : 143
# BMI: 39.121717443395774
# 결과: 과체중
#
# 이름 : 자자
# 몸무게: 53
# 키 : 187
# BMI: 15.156281277703107
# 결과: 저체중
#
# 이름 : 타아
# 몸무게: 86
# 키 : 163
# BMI: 32.36854981369265
# 결과: 과체중
#
# 이름 : 라마
# 몸무게: 53
# 키 : 160
# BMI: 20.703124999999996
# 결과: 정상체중
#
# 이름 : 하사
# 몸무게: 82
# 키 : 161
# BMI: 31.634581999151262
# 결과: 과체중
#
# 이름 : 하사
# 몸무게: 78
# 키 : 170
# BMI: 26.989619377162633
# 결과: 과체중
#
# 이름 : 카사
# 몸무게: 56
# 키 : 141
# BMI: 28.167597203359996
# 결과: 과체중
#
# 이름 : 바사
# 몸무게: 77
# 키 : 148
# BMI: 35.15339663988313
# 결과: 과체중
#
# 이름 : 라바
# 몸무게: 71
# 키 : 167
# BMI: 25.458065904119906
# 결과: 과체중
#
# 이름 : 아자
# 몸무게: 51
# 키 : 150
# BMI: 22.666666666666668
# 결과: 정상체중
#
# 이름 : 자카
# 몸무게: 98
# 키 : 179
# BMI: 30.585811928466654
# 결과: 과체중
#
# 이름 : 라타
# 몸무게: 50
# 키 : 174
# BMI: 16.514731140177037
# 결과: 저체중
#
# 이름 : 자타
# 몸무게: 73
# 키 : 157
# BMI: 29.61580591504726
# 결과: 과체중
#
# 이름 : 카아
# 몸무게: 69
# 키 : 151
# BMI: 30.26183062146397
# 결과: 과체중
#
# 이름 : 하차
# 몸무게: 91
# 키 : 174
# BMI: 30.056810675122207
# 결과: 과체중
#
# 이름 : 마다
# 몸무게: 47
# 키 : 144
# BMI: 22.665895061728396
# 결과: 정상체중
#
# 이름 : 마가
# 몸무게: 77
# 키 : 190
# BMI: 21.329639889196677
# 결과: 정상체중
#
# 이름 : 사가
# 몸무게: 50
# 키 : 169
# BMI: 17.506389832288786
# 결과: 저체중
#
# 이름 : 자사
# 몸무게: 58
# 키 : 146
# BMI: 27.209607806342657
# 결과: 과체중
#
# 이름 : 하파
# 몸무게: 50
# 키 : 183
# BMI: 14.930275612887812
# 결과: 저체중
#
# 이름 : 카타
# 몸무게: 94
# 키 : 167
# BMI: 33.70504499982072
# 결과: 과체중
#
# 이름 : 파나
# 몸무게: 47
# 키 : 157
# BMI: 19.067710657633167
# 결과: 정상체중
#
# 이름 : 차자
# 몸무게: 45
# 키 : 185
# BMI: 13.148283418553687
# 결과: 저체중
#
# 이름 : 나가
# 몸무게: 48
# 키 : 197
# BMI: 12.368265093148496
# 결과: 저체중
#
# 이름 : 자아
# 몸무게: 59
# 키 : 197
# BMI: 15.202659176995027
# 결과: 저체중
#
# 이름 : 가다
# 몸무게: 63
# 키 : 147
# BMI: 29.15451895043732
# 결과: 과체중
#
# 이름 : 라파
# 몸무게: 40
# 키 : 152
# BMI: 17.31301939058172
# 결과: 저체중
#
# 이름 : 아아
# 몸무게: 89
# 키 : 148
# BMI: 40.6318480642805
# 결과: 과체중
#
# 이름 : 마차
# 몸무게: 60
# 키 : 182
# BMI: 18.11375437749064
# 결과: 저체중
#
# 이름 : 다다
# 몸무게: 86
# 키 : 181
# BMI: 26.25072494734593
# 결과: 과체중
#
# 이름 : 하자
# 몸무게: 42
# 키 : 185
# BMI: 12.271731190650108
# 결과: 저체중
#
# 이름 : 카나
# 몸무게: 51
# 키 : 193
# BMI: 13.691642728663858
# 결과: 저체중
#
# 이름 : 자가
# 몸무게: 59
# 키 : 183
# BMI: 17.617725223207618
# 결과: 저체중
#
# 이름 : 마타
# 몸무게: 74
# 키 : 188
# BMI: 20.937075599818925
# 결과: 정상체중
#
# 이름 : 자바
# 몸무게: 89
# 키 : 188
# BMI: 25.18107741059303
# 결과: 과체중
#
# 이름 : 다가
# 몸무게: 75
# 키 : 144
# BMI: 36.16898148148148
# 결과: 과체중
#
# 이름 : 마아
# 몸무게: 44
# 키 : 153
# BMI: 18.79618949976505
# 결과: 정상체중
#
# 이름 : 라다
# 몸무게: 53
# 키 : 182
# BMI: 16.000483033450067
# 결과: 저체중
#
# 이름 : 타다
# 몸무게: 74
# 키 : 175
# BMI: 24.163265306122447
# 결과: 정상체중
#
# 이름 : 아라
# 몸무게: 60
# 키 : 175
# BMI: 19.591836734693878
# 결과: 정상체중
#
# 이름 : 파바
# 몸무게: 45
# 키 : 152
# BMI: 19.47714681440443
# 결과: 정상체중
#
# 이름 : 카다
# 몸무게: 60
# 키 : 158
# BMI: 24.034609838166958
# 결과: 정상체중
#
# 이름 : 마아
# 몸무게: 57
# 키 : 186
# BMI: 16.475893166840095
# 결과: 저체중
#
# 이름 : 타차
# 몸무게: 73
# 키 : 141
# BMI: 36.718474925808565
# 결과: 과체중
#
# 이름 : 마아
# 몸무게: 65
# 키 : 177
# BMI: 20.747550193111813
# 결과: 정상체중
#
# 이름 : 하타
# 몸무게: 60
# 키 : 168
# BMI: 21.258503401360546
# 결과: 정상체중
#
# 이름 : 카아
# 몸무게: 87
# 키 : 169
# BMI: 30.461118308182492
# 결과: 과체중
#
# 이름 : 아파
# 몸무게: 92
# 키 : 143
# BMI: 44.989975059905134
# 결과: 과체중
#
# 이름 : 타가
# 몸무게: 49
# 키 : 170
# BMI: 16.955017301038065
# 결과: 저체중
#
# 이름 : 자자
# 몸무게: 60
# 키 : 160
# BMI: 23.437499999999996
# 결과: 정상체중
#
# 이름 : 사카
# 몸무게: 72
# 키 : 154
# BMI: 30.35925113847192
# 결과: 과체중
#
# 이름 : 자아
# 몸무게: 67
# 키 : 164
# BMI: 24.910767400356935
# 결과: 정상체중
#
# 이름 : 타자
# 몸무게: 66
# 키 : 178
# BMI: 20.830703194041156
# 결과: 정상체중
#
# 이름 : 다라
# 몸무게: 77
# 키 : 169
# BMI: 26.959840341724732
# 결과: 과체중
#
# 이름 : 타하
# 몸무게: 45
# 키 : 158
# BMI: 18.02595737862522
# 결과: 저체중
#
# 이름 : 바카
# 몸무게: 89
# 키 : 188
# BMI: 25.18107741059303
# 결과: 과체중
#
# 이름 : 마아
# 몸무게: 99
# 키 : 182
# BMI: 29.887694722859557
# 결과: 과체중
#
# 이름 : 가바
# 몸무게: 61
# 키 : 169
# BMI: 21.35779559539232
# 결과: 정상체중
#
# 이름 : 마바
# 몸무게: 51
# 키 : 143
# BMI: 24.940094870164803
# 결과: 정상체중
#
# 이름 : 가가
# 몸무게: 78
# 키 : 176
# BMI: 25.180785123966942
# 결과: 과체중
#
# 이름 : 하카
# 몸무게: 79
# 키 : 162
# BMI: 30.102118579484827
# 결과: 과체중
#
# 이름 : 라다
# 몸무게: 84
# 키 : 142
# BMI: 41.65840111089069
# 결과: 과체중
#
# 이름 : 카나
# 몸무게: 57
# 키 : 180
# BMI: 17.59259259259259
# 결과: 저체중
#
# 이름 : 나나
# 몸무게: 78
# 키 : 162
# BMI: 29.721079103795148
# 결과: 과체중
#
# 이름 : 다나
# 몸무게: 96
# 키 : 182
# BMI: 28.982007003985025
# 결과: 과체중
#
# 이름 : 파사
# 몸무게: 63
# 키 : 184
# BMI: 18.608223062381853
# 결과: 정상체중
#
# 이름 : 마파
# 몸무게: 95
# 키 : 156
# BMI: 39.036817882971725
# 결과: 과체중
#
# 이름 : 카나
# 몸무게: 64
# 키 : 190
# BMI: 17.72853185595568
# 결과: 저체중
#
# 이름 : 다아
# 몸무게: 95
# 키 : 145
# BMI: 45.18430439952437
# 결과: 과체중
#
# 이름 : 자하
# 몸무게: 76
# 키 : 159
# BMI: 30.062101973814325
# 결과: 과체중
#
# 이름 : 마아
# 몸무게: 85
# 키 : 152
# BMI: 36.79016620498615
# 결과: 과체중
#
# 이름 : 다사
# 몸무게: 94
# 키 : 153
# BMI: 40.15549574949806
# 결과: 과체중
#
# 이름 : 라가
# 몸무게: 50
# 키 : 178
# BMI: 15.780835753061481
# 결과: 저체중
#
# 이름 : 자자
# 몸무게: 79
# 키 : 157
# BMI: 32.049981743681286
# 결과: 과체중
#
# 이름 : 바마
# 몸무게: 94
# 키 : 159
# BMI: 37.18207349392824
# 결과: 과체중
#
# 이름 : 차차
# 몸무게: 50
# 키 : 141
# BMI: 25.149640360142854
# 결과: 과체중
#
# 이름 : 차마
# 몸무게: 49
# 키 : 146
# BMI: 22.987427284668797
# 결과: 정상체중
#
# 이름 : 바아
# 몸무게: 84
# 키 : 187
# BMI: 24.021275987303035
# 결과: 정상체중
#
# 이름 : 카바
# 몸무게: 54
# 키 : 151
# BMI: 23.683171790710933
# 결과: 정상체중
#
# 이름 : 마다
# 몸무게: 42
# 키 : 184
# BMI: 12.4054820415879
# 결과: 저체중
#
# 이름 : 나파
# 몸무게: 66
# 키 : 191
# BMI: 18.09160933088457
# 결과: 저체중
#
# 이름 : 사바
# 몸무게: 78
# 키 : 181
# BMI: 23.808797045267237
# 결과: 정상체중
#
# 이름 : 타차
# 몸무게: 47
# 키 : 177
# BMI: 15.00207475501931
# 결과: 저체중
#
# 이름 : 마라
# 몸무게: 66
# 키 : 184
# BMI: 19.494328922495274
# 결과: 정상체중
#
# 이름 : 하나
# 몸무게: 52
# 키 : 162
# BMI: 19.81405273586343
# 결과: 정상체중
#
# 이름 : 라다
# 몸무게: 68
# 키 : 144
# BMI: 32.79320987654321
# 결과: 과체중
#
# 이름 : 카자
# 몸무게: 94
# 키 : 171
# BMI: 32.14664341164803
# 결과: 과체중
#
# 이름 : 자카
# 몸무게: 68
# 키 : 193
# BMI: 18.255523638218477
# 결과: 저체중
#
# 이름 : 라아
# 몸무게: 53
# 키 : 176
# BMI: 17.110020661157026
# 결과: 저체중
#
# 이름 : 바가
# 몸무게: 47
# 키 : 177
# BMI: 15.00207475501931
# 결과: 저체중
#
# 이름 : 하하
# 몸무게: 65
# 키 : 142
# BMI: 32.235667526284466
# 결과: 과체중
#
# 이름 : 하타
# 몸무게: 87
# 키 : 155
# BMI: 36.21227887617065
# 결과: 과체중
#
# 이름 : 바라
# 몸무게: 51
# 키 : 142
# BMI: 25.29260067446935
# 결과: 과체중
#
# 이름 : 카바
# 몸무게: 82
# 키 : 157
# BMI: 33.26706965799829
# 결과: 과체중
#
# 이름 : 사파
# 몸무게: 99
# 키 : 181
# BMI: 30.218857788223804
# 결과: 과체중
#
# 이름 : 카가
# 몸무게: 53
# 키 : 184
# BMI: 15.65453686200378
# 결과: 저체중
#
# 이름 : 자가
# 몸무게: 64
# 키 : 171
# BMI: 21.887076365377382
# 결과: 정상체중
#
# 이름 : 나사
# 몸무게: 69
# 키 : 163
# BMI: 25.970115548195267
# 결과: 과체중
#
# 이름 : 마나
# 몸무게: 99
# 키 : 156
# BMI: 40.68047337278106
# 결과: 과체중
#
# 이름 : 나파
# 몸무게: 60
# 키 : 152
# BMI: 25.969529085872576
# 결과: 과체중
#
# 이름 : 마다
# 몸무게: 48
# 키 : 184
# BMI: 14.177693761814744
# 결과: 저체중
#
# 이름 : 바하
# 몸무게: 47
# 키 : 143
# BMI: 22.984008997995016
# 결과: 정상체중
#
# 이름 : 카가
# 몸무게: 56
# 키 : 157
# BMI: 22.7189744005842
# 결과: 정상체중
#
# 이름 : 다차
# 몸무게: 72
# 키 : 184
# BMI: 21.266540642722116
# 결과: 정상체중
#
# 이름 : 차하
# 몸무게: 98
# 키 : 181
# BMI: 29.913616800463966
# 결과: 과체중
#
# 이름 : 다하
# 몸무게: 98
# 키 : 188
# BMI: 27.727478497057493
# 결과: 과체중
#
# 이름 : 나자
# 몸무게: 48
# 키 : 172
# BMI: 16.224986479177936
# 결과: 저체중
#
# 이름 : 바나
# 몸무게: 60
# 키 : 144
# BMI: 28.935185185185187
# 결과: 과체중
#
# 이름 : 파차
# 몸무게: 86
# 키 : 197
# BMI: 22.159808291891057
# 결과: 정상체중
#
# 이름 : 타사
# 몸무게: 90
# 키 : 144
# BMI: 43.40277777777778
# 결과: 과체중
#
# 이름 : 파자
# 몸무게: 69
# 키 : 169
# BMI: 24.158817968558527
# 결과: 정상체중
#
# 이름 : 나파
# 몸무게: 96
# 키 : 196
# BMI: 24.989587671803417
# 결과: 정상체중
#
# 이름 : 아사
# 몸무게: 45
# 키 : 159
# BMI: 17.799928800284796
# 결과: 저체중
#
# 이름 : 파파
# 몸무게: 64
# 키 : 144
# BMI: 30.8641975308642
# 결과: 과체중
#
# 이름 : 바아
# 몸무게: 52
# 키 : 188
# BMI: 14.712539610683569
# 결과: 저체중
#
# 이름 : 마다
# 몸무게: 80
# 키 : 178
# BMI: 25.24933720489837
# 결과: 과체중
#
# 이름 : 파자
# 몸무게: 89
# 키 : 154
# BMI: 37.52740765727779
# 결과: 과체중
#
# 이름 : 자파
# 몸무게: 56
# 키 : 163
# BMI: 21.077195227520797
# 결과: 정상체중
#
# 이름 : 사차
# 몸무게: 41
# 키 : 141
# BMI: 20.62270509531714
# 결과: 정상체중
#
# 이름 : 바카
# 몸무게: 41
# 키 : 182
# BMI: 12.377732157951938
# 결과: 저체중
#
# 이름 : 파바
# 몸무게: 64
# 키 : 193
# BMI: 17.181669306558565
# 결과: 저체중
#
# 이름 : 타카
# 몸무게: 61
# 키 : 156
# BMI: 25.06574621959237
# 결과: 과체중
#
# 이름 : 사라
# 몸무게: 82
# 키 : 197
# BMI: 21.12911953412868
# 결과: 정상체중
#
# 이름 : 자자
# 몸무게: 57
# 키 : 145
# BMI: 27.110582639714625
# 결과: 과체중
#
# 이름 : 차바
# 몸무게: 75
# 키 : 148
# BMI: 34.240321402483566
# 결과: 과체중
#
# 이름 : 하하
# 몸무게: 88
# 키 : 197
# BMI: 22.675152670772242
# 결과: 정상체중
#
# 이름 : 파아
# 몸무게: 46
# 키 : 147
# BMI: 21.28742653523995
# 결과: 정상체중
#
# 이름 : 나타
# 몸무게: 75
# 키 : 186
# BMI: 21.678806798473808
# 결과: 정상체중
#
# 이름 : 자바
# 몸무게: 56
# 키 : 150
# BMI: 24.88888888888889
# 결과: 정상체중
#
# 이름 : 카아
# 몸무게: 44
# 키 : 157
# BMI: 17.85062274331616
# 결과: 저체중
#
# 이름 : 타바
# 몸무게: 78
# 키 : 167
# BMI: 27.968016063681024
# 결과: 과체중
#
# 이름 : 파마
# 몸무게: 77
# 키 : 145
# BMI: 36.6230677764566
# 결과: 과체중
#
# 이름 : 마라
# 몸무게: 82
# 키 : 194
# BMI: 21.787650122223404
# 결과: 정상체중
#
# 이름 : 차사
# 몸무게: 75
# 키 : 191
# BMI: 20.558646966914285
# 결과: 정상체중
#
# 이름 : 카카
# 몸무게: 83
# 키 : 181
# BMI: 25.33500198406642
# 결과: 과체중
#
# 이름 : 사자
# 몸무게: 78
# 키 : 185
# BMI: 22.79035792549306
# 결과: 정상체중
#
# 이름 : 라나
# 몸무게: 95
# 키 : 166
# BMI: 34.47525039918711
# 결과: 과체중
#
# 이름 : 다아
# 몸무게: 41
# 키 : 143
# BMI: 20.049880189740332
# 결과: 정상체중
#
# 이름 : 바마
# 몸무게: 60
# 키 : 188
# BMI: 16.976007243096426
# 결과: 저체중
#
# 이름 : 자자
# 몸무게: 60
# 키 : 188
# BMI: 16.976007243096426
# 결과: 저체중
#
# 이름 : 아아
# 몸무게: 68
# 키 : 183
# BMI: 20.305174833527424
# 결과: 정상체중
#
# 이름 : 바바
# 몸무게: 43
# 키 : 166
# BMI: 15.604587022789955
# 결과: 저체중
#
# 이름 : 아다
# 몸무게: 70
# 키 : 192
# BMI: 18.98871527777778
# 결과: 정상체중
#
# 이름 : 차가
# 몸무게: 57
# 키 : 164
# BMI: 21.192742415229034
# 결과: 정상체중
#
# 이름 : 차가
# 몸무게: 85
# 키 : 176
# BMI: 27.44059917355372
# 결과: 과체중
#
# 이름 : 가가
# 몸무게: 79
# 키 : 172
# BMI: 26.703623580313685
# 결과: 과체중
#
# 이름 : 차아
# 몸무게: 61
# 키 : 178
# BMI: 19.252619618735007
# 결과: 정상체중
#
# 이름 : 나자
# 몸무게: 77
# 키 : 169
# BMI: 26.959840341724732
# 결과: 과체중
#
# 이름 : 차하
# 몸무게: 97
# 키 : 150
# BMI: 43.111111111111114
# 결과: 과체중
#
# 이름 : 파파
# 몸무게: 81
# 키 : 155
# BMI: 33.71488033298647
# 결과: 과체중
#
# 이름 : 카라
# 몸무게: 57
# 키 : 144
# BMI: 27.488425925925927
# 결과: 과체중
#
# 이름 : 나가
# 몸무게: 87
# 키 : 197
# BMI: 22.41748048133165
# 결과: 정상체중
#
# 이름 : 사하
# 몸무게: 46
# 키 : 162
# BMI: 17.527815881725342
# 결과: 저체중
#
# 이름 : 타바
# 몸무게: 42
# 키 : 165
# BMI: 15.426997245179065
# 결과: 저체중
#
# 이름 : 나다
# 몸무게: 49
# 키 : 184
# BMI: 14.473062381852552
# 결과: 저체중
#
# 이름 : 다카
# 몸무게: 71
# 키 : 184
# BMI: 20.97117202268431
# 결과: 정상체중
#
# 이름 : 사카
# 몸무게: 49
# 키 : 182
# BMI: 14.792899408284022
# 결과: 저체중
#
# 이름 : 차바
# 몸무게: 46
# 키 : 179
# BMI: 14.356605599076184
# 결과: 저체중
#
# 이름 : 바바
# 몸무게: 83
# 키 : 181
# BMI: 25.33500198406642
# 결과: 과체중
#
# 이름 : 나나
# 몸무게: 81
# 키 : 149
# BMI: 36.48484302508896
# 결과: 과체중
#
# 이름 : 카나
# 몸무게: 51
# 키 : 160
# BMI: 19.921874999999996
# 결과: 정상체중
#
# 이름 : 차바
# 몸무게: 83
# 키 : 191
# BMI: 22.75156931005181
# 결과: 정상체중
#
# 이름 : 카자
# 몸무게: 70
# 키 : 182
# BMI: 21.132713440405748
# 결과: 정상체중
#
# 이름 : 바하
# 몸무게: 44
# 키 : 181
# BMI: 13.430603461432801
# 결과: 저체중
#
# 이름 : 파차
# 몸무게: 45
# 키 : 199
# BMI: 11.363349410368425
# 결과: 저체중
#
# 이름 : 파하
# 몸무게: 60
# 키 : 168
# BMI: 21.258503401360546
# 결과: 정상체중
#
# 이름 : 바라
# 몸무게: 67
# 키 : 176
# BMI: 21.62964876033058
# 결과: 정상체중
#
# 이름 : 파아
# 몸무게: 87
# 키 : 156
# BMI: 35.74950690335305
# 결과: 과체중
#
# 이름 : 아하
# 몸무게: 75
# 키 : 190
# BMI: 20.775623268698062
# 결과: 정상체중
#
# 이름 : 사하
# 몸무게: 95
# 키 : 150
# BMI: 42.22222222222222
# 결과: 과체중
#
# 이름 : 파아
# 몸무게: 61
# 키 : 142
# BMI: 30.251934140051578
# 결과: 과체중
#
# 이름 : 하가
# 몸무게: 87
# 키 : 157
# BMI: 35.295549515193315
# 결과: 과체중
#
# 이름 : 자바
# 몸무게: 92
# 키 : 187
# BMI: 26.309016557522373
# 결과: 과체중
#
# 이름 : 가다
# 몸무게: 60
# 키 : 149
# BMI: 27.025809648214047
# 결과: 과체중
#
# 이름 : 가가
# 몸무게: 89
# 키 : 182
# BMI: 26.86873565994445
# 결과: 과체중
#
# 이름 : 사아
# 몸무게: 80
# 키 : 159
# BMI: 31.644317867172973
# 결과: 과체중
#
# 이름 : 카사
# 몸무게: 43
# 키 : 142
# BMI: 21.32513390200357
# 결과: 정상체중
#
# 이름 : 카마
# 몸무게: 60
# 키 : 148
# BMI: 27.39225712198685
# 결과: 과체중
#
# 이름 : 차파
# 몸무게: 98
# 키 : 175
# BMI: 32.0
# 결과: 과체중
#
# 이름 : 라사
# 몸무게: 59
# 키 : 182
# BMI: 17.81185847119913
# 결과: 저체중
#
# 이름 : 가아
# 몸무게: 84
# 키 : 172
# BMI: 28.393726338561386
# 결과: 과체중
#
# 이름 : 다바
# 몸무게: 60
# 키 : 167
# BMI: 21.513858510523864
# 결과: 정상체중
#
# 이름 : 나아
# 몸무게: 82
# 키 : 167
# BMI: 29.402273297715947
# 결과: 과체중
#
# 이름 : 자타
# 몸무게: 56
# 키 : 151
# BMI: 24.560326301478007
# 결과: 정상체중
#
# 이름 : 카라
# 몸무게: 63
# 키 : 171
# BMI: 21.545090797168363
# 결과: 정상체중
#
# 이름 : 나자
# 몸무게: 43
# 키 : 156
# BMI: 17.66929651545036
# 결과: 저체중
#
# 이름 : 자가
# 몸무게: 51
# 키 : 181
# BMI: 15.567290375751655
# 결과: 저체중
#
# 이름 : 사하
# 몸무게: 63
# 키 : 168
# BMI: 22.321428571428577
# 결과: 정상체중
#
# 이름 : 타나
# 몸무게: 69
# 키 : 187
# BMI: 19.73176241814178
# 결과: 정상체중
#
# 이름 : 가바
# 몸무게: 86
# 키 : 166
# BMI: 31.20917404557991
# 결과: 과체중
#
# 이름 : 카바
# 몸무게: 44
# 키 : 172
# BMI: 14.872904272579774
# 결과: 저체중
#
# 이름 : 파하
# 몸무게: 57
# 키 : 154
# BMI: 24.034407151290267
# 결과: 정상체중
#
# 이름 : 카라
# 몸무게: 96
# 키 : 144
# BMI: 46.2962962962963
# 결과: 과체중
#
# 이름 : 나가
# 몸무게: 49
# 키 : 155
# BMI: 20.39542143600416
# 결과: 정상체중
#
# 이름 : 바라
# 몸무게: 82
# 키 : 143
# BMI: 40.099760379480664
# 결과: 과체중
#
# 이름 : 아차
# 몸무게: 65
# 키 : 144
# BMI: 31.346450617283953
# 결과: 과체중
#
# 이름 : 다카
# 몸무게: 73
# 키 : 167
# BMI: 26.175194521137367
# 결과: 과체중
#
# 이름 : 라가
# 몸무게: 50
# 키 : 154
# BMI: 21.0828132906055
# 결과: 정상체중
#
# 이름 : 타다
# 몸무게: 56
# 키 : 154
# BMI: 23.61275088547816
# 결과: 정상체중
#
# 이름 : 하나
# 몸무게: 73
# 키 : 166
# BMI: 26.491508201480624
# 결과: 과체중
#
# 이름 : 마차
# 몸무게: 61
# 키 : 199
# BMI: 15.403651422943865
# 결과: 저체중
#
# 이름 : 가자
# 몸무게: 98
# 키 : 172
# BMI: 33.12601406165495
# 결과: 과체중
#
# 이름 : 자파
# 몸무게: 66
# 키 : 193
# BMI: 17.718596472388523
# 결과: 저체중
#
# 이름 : 다타
# 몸무게: 61
# 키 : 160
# BMI: 23.828124999999996
# 결과: 정상체중
#
# 이름 : 타카
# 몸무게: 76
# 키 : 160
# BMI: 29.687499999999993
# 결과: 과체중
#
# 이름 : 차다
# 몸무게: 77
# 키 : 157
# BMI: 31.238589800803275
# 결과: 과체중
#
# 이름 : 차마
# 몸무게: 83
# 키 : 193
# BMI: 22.28247738194314
# 결과: 정상체중
#
# 이름 : 하카
# 몸무게: 53
# 키 : 189
# BMI: 14.837210604406373
# 결과: 저체중
#
# 이름 : 카자
# 몸무게: 44
# 키 : 179
# BMI: 13.73240535563809
# 결과: 저체중
#
# 이름 : 사사
# 몸무게: 85
# 키 : 166
# BMI: 30.84627667295689
# 결과: 과체중
#
# 이름 : 파마
# 몸무게: 67
# 키 : 168
# BMI: 23.738662131519277
# 결과: 정상체중
#
# 이름 : 하다
# 몸무게: 56
# 키 : 155
# BMI: 23.309053069719038
# 결과: 정상체중
#
# 이름 : 가카
# 몸무게: 54
# 키 : 147
# BMI: 24.989587671803417
# 결과: 정상체중
#
# 이름 : 아다
# 몸무게: 41
# 키 : 191
# BMI: 11.23872700857981
# 결과: 저체중
#
# 이름 : 마아
# 몸무게: 91
# 키 : 187
# BMI: 26.023048986244955
# 결과: 과체중
#
# 이름 : 사바
# 몸무게: 70
# 키 : 176
# BMI: 22.59814049586777
# 결과: 정상체중
#
# 이름 : 하차
# 몸무게: 60
# 키 : 142
# BMI: 29.756000793493357
# 결과: 과체중
#
# 이름 : 사하
# 몸무게: 96
# 키 : 182
# BMI: 28.982007003985025
# 결과: 과체중
#
# 이름 : 바다
# 몸무게: 42
# 키 : 150
# BMI: 18.666666666666668
# 결과: 정상체중
#
# 이름 : 바자
# 몸무게: 44
# 키 : 187
# BMI: 12.582573136206353
# 결과: 저체중
#
# 이름 : 자차
# 몸무게: 46
# 키 : 198
# BMI: 11.73349658198143
# 결과: 저체중
#
# 이름 : 카차
# 몸무게: 97
# 키 : 163
# BMI: 36.50871316195567
# 결과: 과체중
#
# 이름 : 바자
# 몸무게: 71
# 키 : 156
# BMI: 29.17488494411571
# 결과: 과체중
#
# 이름 : 타사
# 몸무게: 96
# 키 : 169
# BMI: 33.61226847799447
# 결과: 과체중
#
# 이름 : 자나
# 몸무게: 45
# 키 : 147
# BMI: 20.824656393169516
# 결과: 정상체중
#
# 이름 : 타아
# 몸무게: 73
# 키 : 192
# BMI: 19.80251736111111
# 결과: 정상체중
#
# 이름 : 나마
# 몸무게: 82
# 키 : 190
# BMI: 22.714681440443215
# 결과: 정상체중
#
# 이름 : 자아
# 몸무게: 95
# 키 : 153
# BMI: 40.582681874492714
# 결과: 과체중
#
# 이름 : 아타
# 몸무게: 42
# 키 : 148
# BMI: 19.174579985390796
# 결과: 정상체중
#
# 이름 : 마차
# 몸무게: 93
# 키 : 174
# BMI: 30.71739992072929
# 결과: 과체중
#
# 이름 : 다하
# 몸무게: 52
# 키 : 140
# BMI: 26.530612244897963
# 결과: 과체중
#
# 이름 : 바카
# 몸무게: 45
# 키 : 170
# BMI: 15.570934256055365
# 결과: 저체중
#
# 이름 : 파마
# 몸무게: 63
# 키 : 147
# BMI: 29.15451895043732
# 결과: 과체중
#
# 이름 : 나파
# 몸무게: 42
# 키 : 140
# BMI: 21.42857142857143
# 결과: 정상체중
#
# 이름 : 나차
# 몸무게: 54
# 키 : 163
# BMI: 20.32443825510934
# 결과: 정상체중
#
# 이름 : 하다
# 몸무게: 75
# 키 : 158
# BMI: 30.043262297708697
# 결과: 과체중
#
# 이름 : 마가
# 몸무게: 52
# 키 : 199
# BMI: 13.130981540870179
# 결과: 저체중
#
# 이름 : 라마
# 몸무게: 70
# 키 : 142
# BMI: 34.71533425907558
# 결과: 과체중
#
# 이름 : 하하
# 몸무게: 82
# 키 : 169
# BMI: 28.71047932495361
# 결과: 과체중
#
# 이름 : 다자
# 몸무게: 57
# 키 : 142
# BMI: 28.268200753818686
# 결과: 과체중
#
# 이름 : 차파
# 몸무게: 84
# 키 : 194
# BMI: 22.31905622276544
# 결과: 정상체중
#
# 이름 : 가아
# 몸무게: 98
# 키 : 198
# BMI: 24.997449239873482
# 결과: 정상체중
#
# 이름 : 마가
# 몸무게: 56
# 키 : 149
# BMI: 25.224089004999776
# 결과: 과체중
#
# 이름 : 타자
# 몸무게: 81
# 키 : 173
# BMI: 27.064051588760066
# 결과: 과체중
#
# 이름 : 아타
# 몸무게: 58
# 키 : 154
# BMI: 24.456063417102378
# 결과: 정상체중
#
# 이름 : 라아
# 몸무게: 90
# 키 : 152
# BMI: 38.95429362880886
# 결과: 과체중
#
# 이름 : 자바
# 몸무게: 64
# 키 : 184
# BMI: 18.90359168241966
# 결과: 정상체중
#
# 이름 : 가아
# 몸무게: 67
# 키 : 199
# BMI: 16.918764677659656
# 결과: 저체중
#
# 이름 : 사타
# 몸무게: 43
# 키 : 187
# BMI: 12.296605564928935
# 결과: 저체중
#
# 이름 : 라차
# 몸무게: 61
# 키 : 199
# BMI: 15.403651422943865
# 결과: 저체중
#
# 이름 : 파사
# 몸무게: 53
# 키 : 195
# BMI: 13.93819855358317
# 결과: 저체중
#
# 이름 : 나다
# 몸무게: 92
# 키 : 151
# BMI: 40.349107495285295
# 결과: 과체중
#
# 이름 : 다아
# 몸무게: 73
# 키 : 198
# BMI: 18.62054892357923
# 결과: 정상체중
#
# 이름 : 마다
# 몸무게: 83
# 키 : 174
# BMI: 27.414453692693883
# 결과: 과체중
#
# 이름 : 타하
# 몸무게: 81
# 키 : 190
# BMI: 22.437673130193907
# 결과: 정상체중
#
# 이름 : 자바
# 몸무게: 47
# 키 : 177
# BMI: 15.00207475501931
# 결과: 저체중
#
# 이름 : 마차
# 몸무게: 76
# 키 : 165
# BMI: 27.915518824609737
# 결과: 과체중
#
# 이름 : 타나
# 몸무게: 52
# 키 : 188
# BMI: 14.712539610683569
# 결과: 저체중
#
# 이름 : 마카
# 몸무게: 84
# 키 : 167
# BMI: 30.11940191473341
# 결과: 과체중
#
# 이름 : 나파
# 몸무게: 66
# 키 : 144
# BMI: 31.828703703703706
# 결과: 과체중
#
# 이름 : 타라
# 몸무게: 89
# 키 : 197
# BMI: 22.932824860212836
# 결과: 정상체중
#
# 이름 : 마사
# 몸무게: 81
# 키 : 179
# BMI: 25.280109859242845
# 결과: 과체중
#
# 이름 : 사카
# 몸무게: 81
# 키 : 195
# BMI: 21.301775147928996
# 결과: 정상체중
#
# 이름 : 카마
# 몸무게: 97
# 키 : 167
# BMI: 34.78073792534691
# 결과: 과체중
#
# 이름 : 카차
# 몸무게: 48
# 키 : 155
# BMI: 19.979188345473464
# 결과: 정상체중
#
# 이름 : 아마
# 몸무게: 69
# 키 : 163
# BMI: 25.970115548195267
# 결과: 과체중
#
# 이름 : 가자
# 몸무게: 53
# 키 : 187
# BMI: 15.156281277703107
# 결과: 저체중
#
# 이름 : 마타
# 몸무게: 98
# 키 : 199
# BMI: 24.74684982702457
# 결과: 정상체중
#
# 이름 : 차나
# 몸무게: 54
# 키 : 178
# BMI: 17.043302613306402
# 결과: 저체중
#
# 이름 : 카아
# 몸무게: 82
# 키 : 162
# BMI: 31.24523700655387
# 결과: 과체중
#
# 이름 : 바가
# 몸무게: 64
# 키 : 190
# BMI: 17.72853185595568
# 결과: 저체중
#
# 이름 : 자파
# 몸무게: 76
# 키 : 191
# BMI: 20.832762259806476
# 결과: 정상체중
#
# 이름 : 하아
# 몸무게: 86
# 키 : 158
# BMI: 34.449607434705975
# 결과: 과체중
#
# 이름 : 파라
# 몸무게: 97
# 키 : 194
# BMI: 25.77319587628866
# 결과: 과체중
#
# 이름 : 파라
# 몸무게: 40
# 키 : 189
# BMI: 11.197894795778394
# 결과: 저체중
#
# 이름 : 아하
# 몸무게: 69
# 키 : 196
# BMI: 17.961266139108705
# 결과: 저체중
#
# 이름 : 바마
# 몸무게: 82
# 키 : 141
# BMI: 41.24541019063428
# 결과: 과체중
#
# 이름 : 자마
# 몸무게: 61
# 키 : 153
# BMI: 26.05835362467427
# 결과: 과체중
#
# 이름 : 사아
# 몸무게: 79
# 키 : 150
# BMI: 35.111111111111114
# 결과: 과체중
#
# 이름 : 아자
# 몸무게: 46
# 키 : 153
# BMI: 19.650561749754367
# 결과: 정상체중
#
# 이름 : 다라
# 몸무게: 55
# 키 : 183
# BMI: 16.423303174176592
# 결과: 저체중
#
# 이름 : 하타
# 몸무게: 83
# 키 : 142
# BMI: 41.162467764332476
# 결과: 과체중
#
# 이름 : 카카
# 몸무게: 64
# 키 : 176
# BMI: 20.66115702479339
# 결과: 정상체중
#
# 이름 : 사나
# 몸무게: 43
# 키 : 156
# BMI: 17.66929651545036
# 결과: 저체중
#
# 이름 : 파다
# 몸무게: 95
# 키 : 195
# BMI: 24.983563445101908
# 결과: 정상체중
#
# 이름 : 아아
# 몸무게: 83
# 키 : 184
# BMI: 24.515595463137995
# 결과: 정상체중
#
# 이름 : 차차
# 몸무게: 67
# 키 : 168
# BMI: 23.738662131519277
# 결과: 정상체중
#
# 이름 : 차나
# 몸무게: 70
# 키 : 174
# BMI: 23.120623596247853
# 결과: 정상체중
#
# 이름 : 가파
# 몸무게: 68
# 키 : 152
# BMI: 29.43213296398892
# 결과: 과체중
#
# 이름 : 마아
# 몸무게: 44
# 키 : 192
# BMI: 11.93576388888889
# 결과: 저체중
#
# 이름 : 차하
# 몸무게: 40
# 키 : 140
# BMI: 20.408163265306126
# 결과: 정상체중
#
# 이름 : 라다
# 몸무게: 71
# 키 : 192
# BMI: 19.25998263888889
# 결과: 정상체중
#
# 이름 : 바가
# 몸무게: 89
# 키 : 189
# BMI: 24.915315920606925
# 결과: 정상체중
#
# 이름 : 다카
# 몸무게: 71
# 키 : 151
# BMI: 31.138985132231042
# 결과: 과체중
#
# 이름 : 가자
# 몸무게: 94
# 키 : 161
# BMI: 36.264033023417305
# 결과: 과체중
#
# 이름 : 자다
# 몸무게: 95
# 키 : 191
# BMI: 26.040952824758094
# 결과: 과체중
#
# 이름 : 나타
# 몸무게: 82
# 키 : 188
# BMI: 23.20054323223178
# 결과: 정상체중
#
# 이름 : 사타
# 몸무게: 53
# 키 : 199
# BMI: 13.383500416656144
# 결과: 저체중
#
# 이름 : 라라
# 몸무게: 99
# 키 : 169
# BMI: 34.6626518679318
# 결과: 과체중
#
# 이름 : 파가
# 몸무게: 69
# 키 : 168
# BMI: 24.44727891156463
# 결과: 정상체중
#
# 이름 : 파가
# 몸무게: 67
# 키 : 185
# BMI: 19.576333089846603
# 결과: 정상체중
#
# 이름 : 다라
# 몸무게: 70
# 키 : 186
# BMI: 20.23355301190889
# 결과: 정상체중
#
# 이름 : 하마
# 몸무게: 79
# 키 : 156
# BMI: 32.462195923734384
# 결과: 과체중
#
# 이름 : 타다
# 몸무게: 64
# 키 : 157
# BMI: 25.96454217209623
# 결과: 과체중
#
# 이름 : 파하
# 몸무게: 92
# 키 : 189
# BMI: 25.755158030290307
# 결과: 과체중
#
# 이름 : 자타
# 몸무게: 52
# 키 : 172
# BMI: 17.577068685776098
# 결과: 저체중
#
# 이름 : 가파
# 몸무게: 86
# 키 : 179
# BMI: 26.840610467838083
# 결과: 과체중
#
# 이름 : 마사
# 몸무게: 76
# 키 : 187
# BMI: 21.7335354170837
# 결과: 정상체중
#
# 이름 : 자타
# 몸무게: 68
# 키 : 189
# BMI: 19.03642115282327
# 결과: 정상체중
#
# 이름 : 마자
# 몸무게: 57
# 키 : 145
# BMI: 27.110582639714625
# 결과: 과체중
#
# 이름 : 사다
# 몸무게: 49
# 키 : 176
# BMI: 15.81869834710744
# 결과: 저체중
#
# 이름 : 사하
# 몸무게: 88
# 키 : 176
# BMI: 28.40909090909091
# 결과: 과체중
#
# 이름 : 나자
# 몸무게: 61
# 키 : 175
# BMI: 19.918367346938776
# 결과: 정상체중
#
# 이름 : 하아
# 몸무게: 48
# 키 : 161
# BMI: 18.517804097064154
# 결과: 정상체중
#
# 이름 : 타하
# 몸무게: 73
# 키 : 171
# BMI: 24.96494647925858
# 결과: 정상체중
#
# 이름 : 카차
# 몸무게: 87
# 키 : 179
# BMI: 27.15271058955713
# 결과: 과체중
#
# 이름 : 자가
# 몸무게: 91
# 키 : 162
# BMI: 34.67459228776101
# 결과: 과체중
#
# 이름 : 자바
# 몸무게: 70
# 키 : 160
# BMI: 27.343749999999996
# 결과: 과체중
#
# 이름 : 라가
# 몸무게: 48
# 키 : 140
# BMI: 24.48979591836735
# 결과: 정상체중
#
# 이름 : 다마
# 몸무게: 51
# 키 : 143
# BMI: 24.940094870164803
# 결과: 정상체중
#
# 이름 : 하가
# 몸무게: 57
# 키 : 155
# BMI: 23.725286160249738
# 결과: 정상체중
#
# 이름 : 차가
# 몸무게: 77
# 키 : 190
# BMI: 21.329639889196677
# 결과: 정상체중
#
# 이름 : 사사
# 몸무게: 74
# 키 : 175
# BMI: 24.163265306122447
# 결과: 정상체중
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-ad0c0bbdc63a> in <module>
#       1 with open("data/info.txt","r",encoding="utf-8")as f:
#       2     for person in f:
# ----> 3         name, weight, height=person.strip().split(",")
#       4
#       5         bmi=int(weight) / (int (height)/100)**2
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
data =""

with open("c:/windows/notepad.exe","rb") as f1:
    data=f1.read()
print(data)    
with open("c:/temp/notepad.exe","wb")as f2:
    f2.write(data)
# Out:
# b'MZ\x90\x00\x03\x00\x00\x00\x04\x00\x00\x00\xff\xff\x00\x00\xb8\x00\x00\x00\x00\x00\x00\x00@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xe8\x00\x00\x00\x0e\x1f\xba\x0e\x00\xb4\t\xcd!\xb8\x01L\xcd!This program cannot be run in DOS mode.\r\r\n$\x00\x00\x00\x00\x00\x00\x00\x83\xc22)\xc7\xa3\\z\xc7\xa3\\z\xc7\xa3\\z\xce\xdb\xd8z\xc6\xa3\\z\xce\xdb\xc9z\xc5\xa3\\z\xce\xdb\xcfz\xda\xa3\\z\xc7\xa3]z3\xa3\\z\xce\xdb\xdfz\xd3\xa3\\z\xce\xdb\xd5z\xcc\xa3\\z\xce\xdb\xc8z\xc6\xa3\\z\xce\xdb\xcdz\xc6\xa3\\zRich\xc7\xa3\\z\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00PE\x00\x00d\x86\x06\x00\xb3\xc9[J\x00\x00\x00\x00\x00\x00\x00\x00\xf0\x00"\x00\x0b\x02\t\x00\x00\xa8\x00\x00\x00X\x02\x00\x00\x00\x00\x00p5\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x10\x00\x00\x00\x02\x00\x00\x06\x00\x01\x00\x06\x00\x01\x00\x06\x00\x01\x00\x00\x00\x00\x00\x00P\x03\x00\x00\x06\x00\x00I\xe7\x03\x00\x02\x00@\x81\x00\x00\x08\x00\x00\x00\x00\x00\x00\x10\x01\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf8\xcf\x00\x00,\x01\x00\x00\x00@\x01\x00`\xf1\x01\x00\x000\x01\x00\xb4\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x03\x00\xb8\x00\x00\x00\x10\xb7\x00\x008\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xe0\x02\x00\x008\x01\x00\x00\x00\xc0\x00\x00\xf0\x07\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00.text\x00\x00\x00p\xa7\x00\x00\x00\x10\x00\x00\x00\xa8\x00\x00\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00 \x00\x00`.rdata\x00\x00`1\x00\x00\x00\xc0\x00\x00\x002\x00\x00\x00\xae\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x00\x00@.data\x00\x00\x00D(\x00\x00\x00\x00\x01\x00\x00\x18\x00\x00\x00\xe0\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x00\x00\xc0.pdata\x00\x00\xb4\x06\x00\x00\x000\x01\x00\x00\x08\x00\x00\x00\xf8\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x00\x00@.rsrc\x00\x00\x00`\xf1\x01\x00\x00@\x01\x00\x00\xf2\x01\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x00\x00@.reloc\x00\x00\xb8\x00\x00\x00\x00@\x03\x00\x00\x02\x00\x00\x00\xf2\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x00\x00Bk\xde[J\x90\x00\x00\x00\xdf\xdf[J\x9d\x00\x01\x00+\xe0[J\xaa\x00\x00\x00\x01\xdf[J\xb4\x00\x00\x00\x88\xe0[J\xbe\x00\x01\x00+\xe0[J\xaa\x00\x00\x00\xbe\xdf[J\xc9\x00\x01\x00+\xe0[J\xaa\x00\x00\x00v\xdf[J\xd4\x00\x00\x00T\xe0[J\xe1\x00\x00\x00\xbf\xe0[J\xed\x00\x00\x00\x1a\xe0[J\xfa\x00\x00\x00Y\xe0[J\x04\x01\x00\x00g\xde[J\x10\x01\x00\x00\x1e\xe0[J\x1d\x01\x00\x00+\xe0[J\xaa\x00\x00\x00\x82\xe0[J*\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00ADVAPI32.dll\x00KERNEL32.dll\x00NTDLL.DLL\x00GDI32.dll\x00USER32.dll\x00msvcrt.dll\x00COMDLG32.dll\x00SHELL32.dll\x00WINSPOOL.DRV\x00ole32.dll\x00SHLWAPI.dll\x00COMCTL32.dll\x00OLEAUT32.dll\x00VERSION.dll\x00\x00\x00A;\xc4\x0f\x84\xfcE\x00\x00\xff\x15\xa1\xb1\x00\x00\xb9\x0b\x80\x00\x00D\x89d$0L\x8d\r \x06\x00\x00\x8b\xd1E3\xc0D\x89d$(\x89D$ \xff\x15D\xb4\x00\x00H\x8b\xd8\xeb\x00H\x8dL$@E3\xc9E3\xc03\xd2\xff\x15$\xb4\x00\x00A;\xc4\x0f\x84\xb2\x06\x00\x00\x83|$HP\x0f\x84nE\x00\x00H\x8b\r\xa1\xfa\x00\x00I;\xcc\x0f\x85|E\x00\x00H\x8b\x151\xf0\x00\x00H\x8b\r\xfa\xef\x00\x00L\x8dD$@\xff\x15\xd7\xb3\x00\x00A;\xc4u\xabH\x8dL$@\xff\x15\xbf\xb3\x00\x00H\x8dL$@\xff\x15\xac\xb3\x00\x00\x90\xeb\x92\x90\x90\x90\x90\x90\x90\x90\x90\x90H\x8b\xc4H\x89X\x08H\x89h\x10H\x89p\x18L\x89H WATAUH\x83\xec I\x8b\xe9I\x8b\xf0D\x8b\xeaL\x8b\xe1\x83\xfa\x1cv~\x8b\xc2\xbf\x01\x00\x00\x00-\x11\x01\x00\x00\x0f\x84\xaa\x03\x00\x00+\xc7\x0f\x84P\x05\x00\x00\x83\xe8\x04\x0f\x84\xe1\x06\x00\x00+\xc7\x0f\x84\xc6\x06\x00\x00-\x1c\x01\x00\x00\x0f\x84\x15D\x00\x00-\xe6\x00\x00\x00\x0f\x84\xdaC\x00\x00=\xe8|\ ...
